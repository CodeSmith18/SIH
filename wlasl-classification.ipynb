# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### **<font style="color:#112B3C"> Import the Libraries</font>**
#
# We will start by installing and importing the required libraries.

# %%
pip install ez_setup
# Out:
# Requirement already satisfied: ez_setup in /usr/local/lib/python3.11/dist-packages (0.9)

# %%
pip install moviepy
# Out:
# Requirement already satisfied: moviepy in /usr/local/lib/python3.11/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.6.0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.67.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.0.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio<3.0,>=2.5->moviepy) (11.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2025.1.31)

# %%
# !pip install pafy
# Out:
# Requirement already satisfied: pafy in /usr/local/lib/python3.11/dist-packages (0.5.5)

# %%
# !pip install youtube-dl
# Out:
# Requirement already satisfied: youtube-dl in /usr/local/lib/python3.11/dist-packages (2021.12.17)

# %%
pip install youtube-dl==2020.12.2
# Out:
# Collecting youtube-dl==2020.12.2
#   Using cached youtube_dl-2020.12.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Using cached youtube_dl-2020.12.2-py2.py3-none-any.whl (1.8 MB)
# Installing collected packages: youtube-dl
#   Attempting uninstall: youtube-dl
#     Found existing installation: youtube-dl 2021.12.17
#     Uninstalling youtube-dl-2021.12.17:
#       Successfully uninstalled youtube-dl-2021.12.17
# Successfully installed youtube-dl-2020.12.2

# %%
# import required libraries
import json
import os
import cv2
import pandas as pd
import pafy
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from moviepy import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

# %%
seed_constant = 42
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
main_path = 'wlasl-processed/'
wlas_df = pd.read_json(main_path + 'WLASL_v0.3.json')

# %% [markdown]
#  ### **<font style="color:#112B3C">Load WLAS Dataset</font>**

# %%
wlas_df.head()
# Out:
#       gloss                                          instances
# 0      book  [{'bbox': [385, 37, 885, 720], 'fps': 25, 'fra...
# 1     drink  [{'bbox': [551, 68, 1350, 1080], 'fps': 25, 'f...
# 2  computer  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 3    before  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 4     chair  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...

# %%
wlas_df.shape
# Out:
# (2000, 2)

# %% [markdown]
# ### **<font style="color:#112B3C">Extract the available videos list from the dataset</font>**

# %%
def get_videos_ids(json_list):
    """
    function to check if the video id is available in the dataset
    and return the viedos ids of the current instance

    input: instance json list
    output: list of videos_ids

    """
    videos_list = []
    for ins in json_list:
        video_id = ins['video_id']
        if os.path.exists(f'{main_path}videos/{video_id}.mp4'):
            videos_list.append(video_id)
    return videos_list

# %%
def get_json_features(json_list):
    """
    function to check if the video id is available in the dataset
    and return the viedos ids and url or any other featrue of the current instance

    input: instance json list
    output: list of videos_ids

    """
    videos_ids = []
    videos_urls = []
    for ins in json_list:
        video_id = ins['video_id']
        video_url = ins['url']
        if os.path.exists(f'{main_path}videos/{video_id}.mp4'):
            videos_ids.append(video_id)
            videos_urls.append(video_url)
    return videos_ids, videos_urls

# %%
with open(main_path+'WLASL_v0.3.json', 'r') as data_file:
    json_data = data_file.read()

instance_json = json.loads(json_data)

# %%
get_videos_ids(instance_json[0]['instances'])[0]
# Out:
# '69241'

# %%
len(get_videos_ids(instance_json[0]['instances']))
# Out:
# 6

# %%
wlas_df['videos_ids'] = wlas_df['instances'].apply(get_videos_ids)

# %%
features_df = pd.DataFrame(columns=['gloss', 'video_id', 'url'])
for row in wlas_df.iterrows():
#     print(row[1][1])
    ids, urls = get_json_features(row[1][1])
    word = [row[1][0]] * len(ids)
    df = pd.DataFrame(list(zip(word, ids, urls)), columns = features_df.columns)
    # Use pd.concat instead of features_df.concat
    features_df = pd.concat([features_df, df], ignore_index=True)
# Out:
# <ipython-input-26-f30bab9d68b1>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ids, urls = get_json_features(row[1][1])
# <ipython-input-26-f30bab9d68b1>:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   word = [row[1][0]] * len(ids)

# %%
features_df.index.name = 'index'
features_df
# Out:
#             gloss video_id                                                url
# index
# 0            book    69241       http://aslbricks.org/New/ASL-Videos/book.mp4
# 1            book    07069  https://signstock.blob.core.windows.net/signsc...
# 2            book    07068  https://s3-us-west-1.amazonaws.com/files.start...
# 3            book    07070  https://media.asldeafined.com/vocabulary/14666...
# 4            book    07099     http://www.aslsearch.com/signs/videos/book.mp4
# ...           ...      ...                                                ...
# 11975  wheelchair    63047  https://www.signingsavvy.com/signs/mp4/5/5233.mp4
# 11976  wheelchair    63050  http://www.aslsearch.com/signs/videos/wheelcha...
# 11977     whistle    63186  https://media.spreadthesign.com/video/mp4/13/9...
# 11978     whistle    63188  https://www.signingsavvy.com/signs/mp4/9/9961.mp4
# 11979     whistle    63190  http://www.aslsearch.com/signs/videos/whistle.mp4
#
# [11980 rows x 3 columns]

# %%
# save to csv
#features_df.to_csv('features_df.csv', index=False)

# %% [markdown]
# ## **<font style="color:#112B3C">Explore the Data</font>**

# %%
wlas_df.head()
# Out:
#       gloss                                          instances  \
# 0      book  [{'bbox': [385, 37, 885, 720], 'fps': 25, 'fra...
# 1     drink  [{'bbox': [551, 68, 1350, 1080], 'fps': 25, 'f...
# 2  computer  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 3    before  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 4     chair  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
#
#                                           videos_ids
# 0         [69241, 07069, 07068, 07070, 07099, 07074]
# 1  [69302, 65539, 17710, 17733, 65540, 17734, 177...
# 2  [12328, 12312, 12311, 12338, 12313, 12314, 123...
# 3  [05728, 05749, 05750, 05729, 05730, 65167, 057...
# 4  [09848, 09869, 09849, 09850, 09851, 65328, 09854]

# %% [markdown]
# ## **<font style="color:#205375">Dataset Classes analysis</font>**

# %%
wlas_df['samples_num'] = wlas_df['videos_ids'].apply(len)

# %%
wlas_df.head()
# Out:
#       gloss                                          instances  \
# 0      book  [{'bbox': [385, 37, 885, 720], 'fps': 25, 'fra...
# 1     drink  [{'bbox': [551, 68, 1350, 1080], 'fps': 25, 'f...
# 2  computer  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 3    before  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 4     chair  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
#
#                                           videos_ids  samples_num
# 0         [69241, 07069, 07068, 07070, 07099, 07074]            6
# 1  [69302, 65539, 17710, 17733, 65540, 17734, 177...           15
# 2  [12328, 12312, 12311, 12338, 12313, 12314, 123...           14
# 3  [05728, 05749, 05750, 05729, 05730, 65167, 057...           16
# 4  [09848, 09869, 09849, 09850, 09851, 65328, 09854]            7

# %%
print("minimum number of samples for a word:", wlas_df['samples_num'].min())
print("maximum number of samples for a word:", wlas_df['samples_num'].max())
# Out:
# minimum number of samples for a word: 2
# maximum number of samples for a word: 16

# %%
words_sample_counts = wlas_df[['gloss', 'samples_num']].groupby('samples_num').agg({"gloss":['count', ', '.join]})

# %%
words_sample_counts
# Out:
#             gloss
#             count                                               join
# samples_num
# 2              14  gloves, careless, wash face, curtain, grey, la...
# 3              76  garage, parents, boots, excuse, furniture, rep...
# 4             335  hello, newspaper, asl, that, will, cards, hate...
# 5             511  clothes, table, movie, clock, pencil, behind, ...
# 6             402  book, birthday, need, have, knife, read, name,...
# 7             307  chair, dance, eat, forget, but, jacket, paint,...
# 8             151  all, blue, hearing, wrong, color, enjoy, time,...
# 9             100  fine, finish, now, can, hat, kiss, cow, meet, ...
# 10             48  year, black, hot, like, many, orange, fish, gr...
# 11             26  deaf, no, walk, mother, woman, dog, family, ap...
# 12             13  yes, what, later, man, shirt, change, corn, da...
# 13              8  candy, thanksgiving, bed, bowling, tall, accid...
# 14              4                        computer, who, cousin, help
# 15              2                                          drink, go
# 16              3                                 before, thin, cool

# %%
# the words that have two samples
words_sample_counts.loc[2].values[1]
# Out:
# 'gloves, careless, wash face, curtain, grey, lamp, look at, meaning, post, propaganda, ski, smoking, stepfather, tv'

# %% [markdown]
# ### **<font style="color:#205375">Visualize the Data with its Labels</font>**

# %%
features_df
# Out:
#             gloss video_id                                                url
# index
# 0            book    69241       http://aslbricks.org/New/ASL-Videos/book.mp4
# 1            book    07069  https://signstock.blob.core.windows.net/signsc...
# 2            book    07068  https://s3-us-west-1.amazonaws.com/files.start...
# 3            book    07070  https://media.asldeafined.com/vocabulary/14666...
# 4            book    07099     http://www.aslsearch.com/signs/videos/book.mp4
# ...           ...      ...                                                ...
# 11975  wheelchair    63047  https://www.signingsavvy.com/signs/mp4/5/5233.mp4
# 11976  wheelchair    63050  http://www.aslsearch.com/signs/videos/wheelcha...
# 11977     whistle    63186  https://media.spreadthesign.com/video/mp4/13/9...
# 11978     whistle    63188  https://www.signingsavvy.com/signs/mp4/9/9961.mp4
# 11979     whistle    63190  http://www.aslsearch.com/signs/videos/whistle.mp4
#
# [11980 rows x 3 columns]

# %%
# get all categories classes
all_classes = features_df.gloss.value_counts().keys().to_list()
all_classes
# Out:
# ['thin',
#  'before',
#  'cool',
#  'drink',
#  'go',
#  'cousin',
#  'who',
#  'help',
#  'computer',
#  'tall',
#  'short',
#  'candy',
#  'trade',
#  'bed',
#  'accident',
#  'bowling',
#  'thanksgiving',
#  'dark',
#  'pizza',
#  'last',
#  'cold',
#  'man',
#  'call',
#  'corn',
#  'later',
#  'basketball',
#  'change',
#  'what',
#  'yes',
#  'shirt',
#  'bar',
#  'thursday',
#  'why',
#  'brother',
#  'laugh',
#  'environment',
#  'room',
#  'deaf',
#  'no',
#  'walk',
#  'apple',
#  'letter',
#  'play',
#  'check',
#  'score',
#  'take',
#  'far',
#  'woman',
#  'family',
#  'example',
#  'leave',
#  'soon',
#  'mother',
#  'delay',
#  'dog',
#  'champion',
#  'delicious',
#  'because',
#  'speech',
#  'perspective',
#  'cheat',
#  'sweet',
#  'blanket',
#  'appointment',
#  'doctor',
#  'bird',
#  'secretary',
#  'son',
#  'full',
#  'work',
#  'tell',
#  'give',
#  'language',
#  'cry',
#  'wait',
#  'white',
#  'balance',
#  'convince',
#  'year',
#  'graduate',
#  'fish',
#  'hot',
#  'like',
#  'study',
#  'black',
#  'theory',
#  'sandwich',
#  'interest',
#  'orange',
#  'many',
#  'fat',
#  'government',
#  'ready',
#  'move',
#  'order',
#  'argue',
#  'good',
#  'bad',
#  'daughter',
#  'yesterday',
#  'toast',
#  'snow',
#  'write',
#  'silly',
#  'fine',
#  'right',
#  'cow',
#  'how',
#  'hair',
#  'headache',
#  'inform',
#  'voice',
#  'today',
#  'alone',
#  'wet',
#  'vomit',
#  'same',
#  'add',
#  'wow',
#  'city',
#  'class',
#  'want',
#  'water',
#  'visit',
#  'decide',
#  'meet',
#  'school',
#  'pink',
#  'pull',
#  'africa',
#  'australia',
#  'balloon',
#  'kiss',
#  'near',
#  'tiger',
#  'week',
#  'show',
#  'decorate',
#  'cat',
#  'ball',
#  'california',
#  'weekend',
#  'ago',
#  'glasses',
#  'animal',
#  'halloween',
#  'catch',
#  'baby',
#  'chat',
#  'list',
#  'outside',
#  'careful',
#  'lose',
#  'shock',
#  'stay',
#  'problem',
#  'first',
#  'buy',
#  'follow',
#  'child',
#  'dry',
#  'dive',
#  'dirty',
#  'fast',
#  'point',
#  'improve',
#  'necklace',
#  'minute',
#  'town',
#  'fault',
#  'great',
#  'banana',
#  'make',
#  'carrot',
#  'ugly',
#  'new',
#  'office',
#  'party',
#  'past',
#  'practice',
#  'sign',
#  'president',
#  'correct',
#  'big',
#  'country',
#  'form',
#  'upset',
#  'train',
#  'beard',
#  'football',
#  'future',
#  'travel',
#  'day',
#  'crash',
#  'drop',
#  'hope',
#  'finish',
#  'now',
#  'grammar',
#  'girl',
#  'hear',
#  'hat',
#  'can',
#  'barely',
#  'cancel',
#  'choice',
#  'dessert',
#  'dollar',
#  'enjoy',
#  'blue',
#  'all',
#  'allergy',
#  'demand',
#  'develop',
#  'ride',
#  'russia',
#  'join',
#  'light',
#  'mean',
#  'cop',
#  'cloud',
#  'strawberry',
#  'music',
#  'pants',
#  'awful',
#  'bark',
#  'beer',
#  'bitter',
#  'cake',
#  'rob',
#  'salt',
#  'since',
#  'small',
#  'student',
#  'tomato',
#  'underwear',
#  'exchange',
#  'face',
#  'front',
#  'more',
#  'christmas',
#  'close',
#  'discuss',
#  'dress',
#  'special',
#  'helicopter',
#  'history',
#  'you',
#  'approve',
#  'arrive',
#  'boy',
#  'transfer',
#  'weather',
#  'accept',
#  'allow',
#  'heart',
#  'bring',
#  'cereal',
#  'postpone',
#  'come here',
#  'late',
#  'police',
#  'shine',
#  'sky',
#  'again',
#  'sunday',
#  'test',
#  'copy',
#  'present',
#  'one',
#  'stink',
#  'sunset',
#  'east',
#  'possible',
#  'scared',
#  'sad',
#  'save',
#  'farm',
#  'humble',
#  'internet',
#  'match',
#  'meat',
#  'slow',
#  'overwhelm',
#  'presentation',
#  'mirror',
#  'miss',
#  'onion',
#  'idea',
#  'important',
#  'jealous',
#  'disconnect',
#  'potato',
#  'lemon',
#  'spin',
#  'ear',
#  'escape',
#  'expensive',
#  'find',
#  'fly',
#  'smart',
#  'soft',
#  'spray',
#  'stress',
#  'strong',
#  'happy',
#  'know',
#  'sick',
#  'teacher',
#  'with',
#  'choose',
#  'cookie',
#  'cut',
#  'deep',
#  'dentist',
#  'down',
#  'card',
#  'scissors',
#  'secret',
#  'different',
#  'learn',
#  'rabbit',
#  'group',
#  'her',
#  'tease',
#  'thirsty',
#  'watch',
#  'straight',
#  'temperature',
#  'tent',
#  'cafeteria',
#  'vote',
#  'wednesday',
#  'west',
#  'when',
#  'word',
#  'already',
#  'analyze',
#  'wife',
#  'yellow',
#  'backpack',
#  'cook',
#  'medicine',
#  'paper',
#  'boat',
#  'wind',
#  'purple',
#  'time',
#  'hearing',
#  'brown',
#  'wrong',
#  'color',
#  'blind',
#  'bother',
#  'bottom',
#  'peaceful',
#  'bottle',
#  'boss',
#  'take turns',
#  'recent',
#  'but',
#  'jacket',
#  'paint',
#  'benefit',
#  'expert',
#  'forest',
#  'frog',
#  'goal',
#  'golf',
#  'wedding',
#  'airplane',
#  'also',
#  'angry',
#  'red',
#  'structure',
#  'elephant',
#  'explain',
#  'fight',
#  'from',
#  'car',
#  'deer',
#  'age',
#  'chop',
#  'christian',
#  'cochlear implant',
#  'sister',
#  'sorry',
#  'talk',
#  'thank you',
#  'bread',
#  'dinner',
#  'dinosaur',
#  'discover',
#  'educate',
#  'niece',
#  'north',
#  'not',
#  'off',
#  'ok',
#  'patient',
#  'pay',
#  'lettuce',
#  'service',
#  'stare',
#  'store',
#  'straw',
#  'monkey',
#  'motorcycle',
#  'never',
#  'pepper',
#  'quick',
#  'rehearse',
#  'remove',
#  'review',
#  'get',
#  'hospital',
#  'japan',
#  'king',
#  'kitchen',
#  'large',
#  'think',
#  'throw',
#  'shape',
#  'saturday',
#  'flexible',
#  'fun',
#  'hour',
#  'hurry',
#  'kill',
#  'law',
#  'month',
#  'napkin',
#  'open',
#  'perfect',
#  'private',
#  'procrastinate',
#  'project',
#  'marry',
#  'linguistics',
#  'middle',
#  'disappear',
#  'egg',
#  'father',
#  'flower',
#  'friendly',
#  'tomorrow',
#  'lead',
#  'memorize',
#  'plus',
#  'quiet',
#  'rain',
#  'research',
#  'science',
#  'sentence',
#  'cheese',
#  'crazy',
#  'answer',
#  'herself',
#  'highway',
#  'ice cream',
#  'information',
#  'snake',
#  'soap',
#  'star',
#  'struggle',
#  'stubborn',
#  'surgery',
#  'moon',
#  'glass',
#  'iran',
#  'some',
#  'south',
#  'teach',
#  'fancy',
#  'finally',
#  'fox',
#  'fruit',
#  'function',
#  'hawaii',
#  'adult',
#  'after',
#  'angel',
#  'always',
#  'back',
#  'bake',
#  'bath',
#  'war',
#  'where',
#  'none',
#  'plan',
#  'please',
#  'contact',
#  'encourage',
#  'evidence',
#  'area',
#  'art',
#  'aunt',
#  'awkward',
#  'bacon',
#  'belt',
#  'represent',
#  'result',
#  'here',
#  'house',
#  'husband',
#  'care',
#  'carry',
#  'chain',
#  'character',
#  'contribute',
#  'dad',
#  'describe',
#  'dissolve',
#  'canada',
#  'cheap',
#  'clean',
#  'compare',
#  'complex',
#  'children',
#  'drive',
#  'god',
#  'autumn',
#  'beautiful',
#  'brush',
#  'depend',
#  'desert',
#  'doll',
#  'easter',
#  'egypt',
#  'europe',
#  'event',
#  'caption',
#  'restaurant',
#  'a lot',
#  'calculate',
#  'about',
#  'business',
#  'swallow',
#  'to',
#  'translate',
#  'up',
#  'violin',
#  'volunteer',
#  'experience',
#  'food',
#  'freeze',
#  'giraffe',
#  'most',
#  'beginning',
#  'belief',
#  'pig',
#  'center',
#  'old',
#  'person',
#  'remember',
#  'share',
#  'power',
#  'sour',
#  'spirit',
#  'steal',
#  'grandfather',
#  'greece',
#  'guitar',
#  'invest',
#  'lie',
#  'feel',
#  'raccoon',
#  'really',
#  'reason',
#  'religion',
#  'respect',
#  'sell',
#  'quit',
#  'retire',
#  'rise',
#  'rough',
#  'lobster',
#  'love',
#  'lucky',
#  'measure',
#  'microwave',
#  'neighbor',
#  'tired',
#  'coffee',
#  'college',
#  'cute',
#  'friend',
#  'listen',
#  'march',
#  'math',
#  'mom',
#  'must',
#  'negative',
#  'nervous',
#  'opinion',
#  'pass',
#  'pillow',
#  'prepare',
#  'themselves',
#  'tuesday',
#  'turkey',
#  'university',
#  'until',
#  'weak',
#  'smile',
#  'sound',
#  'stomach',
#  'story',
#  'strange',
#  'sugar',
#  'lecture',
#  'limit',
#  'home',
#  'tea',
#  'run',
#  'bathroom',
#  'document',
#  'gas',
#  'geography',
#  'professional',
#  'door',
#  'green',
#  'appear',
#  'arm',
#  'grandmother',
#  'grapes',
#  'guilty',
#  'in',
#  'independent',
#  'summer',
#  'chair',
#  'obsess',
#  'calm',
#  'comfortable',
#  'conflict',
#  'destroy',
#  'drawer',
#  'drunk',
#  'eagle',
#  'asia',
#  'ask',
#  'attitude',
#  'bald',
#  'eat',
#  'forget',
#  'dance',
#  'we',
#  'without',
#  'understand',
#  'win',
#  'afternoon',
#  'third',
#  'three',
#  'tie',
#  'topic',
#  'tournament',
#  'avoid',
#  'bear',
#  'believe',
#  'bored',
#  'box',
#  'bracelet',
#  'spell',
#  'need',
#  'spring',
#  'silver',
#  'siren',
#  'skin',
#  'borrow',
#  'experiment',
#  'fact',
#  'feedback',
#  'fold',
#  'france',
#  'butter',
#  'candle',
#  'comb',
#  'deodorant',
#  'diamond',
#  'hamburger',
#  'head',
#  'impossible',
#  'inside',
#  'insurance',
#  'arrest',
#  'attract',
#  'baseball',
#  'bite',
#  'blame',
#  'body',
#  'temple',
#  'tender',
#  'thailand',
#  'tissue',
#  'senior',
#  'have',
#  'knife',
#  'read',
#  'quote',
#  'soup',
#  'spain',
#  'squirrel',
#  'street',
#  'strict',
#  'lesson',
#  'maybe',
#  'mechanic',
#  'sixteen',
#  'sprint',
#  'gossip',
#  'world',
#  'nose',
#  'often',
#  'operate',
#  'program',
#  'put',
#  'price',
#  'island',
#  'suspect',
#  'sweetheart',
#  'therapy',
#  'ticket',
#  'top',
#  'politics',
#  'pound',
#  'wallet',
#  'weight',
#  'whale',
#  'over',
#  'single',
#  'queen',
#  'radio',
#  'rat',
#  'require',
#  'rest',
#  'much',
#  'neutral',
#  'physician',
#  'mix',
#  'network',
#  'nineteen',
#  'wrap',
#  'adapt',
#  'agreement',
#  'peach',
#  'polite',
#  'should',
#  'skinny',
#  'skirt',
#  'prison',
#  'push',
#  'rule',
#  'salad',
#  'serious',
#  'laptop',
#  'lift',
#  'lightning',
#  'between',
#  'infection',
#  'bush',
#  'cannot',
#  'high',
#  'hungry',
#  'introduce',
#  'lazy',
#  'television',
#  'together',
#  'triangle',
#  'seem',
#  'my',
#  'forever',
#  'french fries',
#  'eye',
#  'fake',
#  'flute',
#  'dangerous',
#  'witness',
#  'wood',
#  'across',
#  'actor',
#  'sculpture',
#  'guess',
#  'hammer',
#  'disgust',
#  'name',
#  'dorm',
#  'eighteen',
#  'due',
#  'constitution',
#  'crab',
#  'deduct',
#  'ceiling',
#  'cemetery',
#  'choir',
#  'come',
#  'window',
#  'below',
#  'bet',
#  'bicycle',
#  'biology',
#  'wash',
#  'fail',
#  'feed',
#  'flag',
#  'friday',
#  'confront',
#  'confused',
#  'congress',
#  'dull',
#  'email',
#  'end',
#  'celebrate',
#  'certificate',
#  'chase',
#  'apartment',
#  'attention',
#  'audience',
#  'august',
#  'away',
#  'bully',
#  'game',
#  'live',
#  'get up',
#  'affect',
#  'cracker',
#  'curious',
#  'curriculum',
#  'diaper',
#  'diarrhea',
#  'divide',
#  'building',
#  'desk',
#  'dictionary',
#  'elevator',
#  'angle',
#  'apostrophe',
#  'wide',
#  'willing',
#  'wonderful',
#  'worse',
#  'double',
#  'doubt',
#  'earth',
#  'eight',
#  'embarrass',
#  'emotion',
#  'community',
#  'complain',
#  'compromise',
#  'cost',
#  'action',
#  'tooth',
#  'tough',
#  'trust',
#  'while',
#  'subtract',
#  'expect',
#  'bedroom',
#  'both',
#  'gather',
#  'germany',
#  'goat',
#  'cause',
#  'challenge',
#  'chocolate',
#  'continue',
#  'curse',
#  'surface',
#  'switzerland',
#  'tale',
#  'terrible',
#  'similar',
#  'six',
#  'sketch',
#  'tree',
#  'truck',
#  'uncle',
#  'vacation',
#  'america',
#  'honor',
#  'if',
#  'energy',
#  'exact',
#  'your',
#  'slip',
#  'snob',
#  'specific',
#  'steel',
#  'rock',
#  'land',
#  'lesbian',
#  'line',
#  'lock',
#  'loud',
#  'lousy',
#  'lunch',
#  'recover',
#  'relief',
#  'grow',
#  'gum',
#  'seven',
#  'she',
#  'jewelry',
#  'refuse',
#  'divorce',
#  'draw',
#  'sit',
#  'neck',
#  'jesus',
#  'keep',
#  'keyboard',
#  'soda',
#  'there',
#  'easy',
#  'hard',
#  'cough',
#  'responsibility',
#  'motivate',
#  'path',
#  'physics',
#  'popular',
#  'pray',
#  'predict',
#  'print',
#  'printer',
#  'protect',
#  'provide',
#  'psychology',
#  'machine',
#  'monday',
#  'picture',
#  'poor',
#  'pocket',
#  'proof',
#  'purpose',
#  'race',
#  'mexico',
#  'multiply',
#  'myself',
#  'people',
#  'puzzled',
#  'revenge',
#  'rich',
#  'rude',
#  'parade',
#  'philosophy',
#  'policy',
#  'nothing',
#  'offer',
#  'only',
#  'key',
#  'label',
#  'leaf',
#  'lend',
#  'second',
#  'senate',
#  'separate',
#  'shrimp',
#  'shy',
#  'situation',
#  'publish',
#  'punish',
#  'meeting',
#  'morning',
#  'lonely',
#  'maximum',
#  'health',
#  'stairs',
#  'suggest',
#  'sun',
#  'support',
#  'surprise',
#  'sweater',
#  'say',
#  'scotland',
#  'happen',
#  'hit',
#  'investigate',
#  'last year',
#  'screwdriver',
#  'influence',
#  'interesting',
#  'notice',
#  'birthday',
#  'floor',
#  'church',
#  'cup',
#  'taste',
#  'team',
#  'telephone',
#  'tennis',
#  'slave',
#  'socks',
#  'solid',
#  'spider',
#  'jump',
#  'money',
#  'general',
#  'ghost',
#  'give up',
#  ...]

# %%
classes_dict = {}
for i in range(len(all_classes)):
    classes_dict[all_classes[i]] = i

classes_dict
# Out:
# {'thin': 0,
#  'before': 1,
#  'cool': 2,
#  'drink': 3,
#  'go': 4,
#  'cousin': 5,
#  'who': 6,
#  'help': 7,
#  'computer': 8,
#  'tall': 9,
#  'short': 10,
#  'candy': 11,
#  'trade': 12,
#  'bed': 13,
#  'accident': 14,
#  'bowling': 15,
#  'thanksgiving': 16,
#  'dark': 17,
#  'pizza': 18,
#  'last': 19,
#  'cold': 20,
#  'man': 21,
#  'call': 22,
#  'corn': 23,
#  'later': 24,
#  'basketball': 25,
#  'change': 26,
#  'what': 27,
#  'yes': 28,
#  'shirt': 29,
#  'bar': 30,
#  'thursday': 31,
#  'why': 32,
#  'brother': 33,
#  'laugh': 34,
#  'environment': 35,
#  'room': 36,
#  'deaf': 37,
#  'no': 38,
#  'walk': 39,
#  'apple': 40,
#  'letter': 41,
#  'play': 42,
#  'check': 43,
#  'score': 44,
#  'take': 45,
#  'far': 46,
#  'woman': 47,
#  'family': 48,
#  'example': 49,
#  'leave': 50,
#  'soon': 51,
#  'mother': 52,
#  'delay': 53,
#  'dog': 54,
#  'champion': 55,
#  'delicious': 56,
#  'because': 57,
#  'speech': 58,
#  'perspective': 59,
#  'cheat': 60,
#  'sweet': 61,
#  'blanket': 62,
#  'appointment': 63,
#  'doctor': 64,
#  'bird': 65,
#  'secretary': 66,
#  'son': 67,
#  'full': 68,
#  'work': 69,
#  'tell': 70,
#  'give': 71,
#  'language': 72,
#  'cry': 73,
#  'wait': 74,
#  'white': 75,
#  'balance': 76,
#  'convince': 77,
#  'year': 78,
#  'graduate': 79,
#  'fish': 80,
#  'hot': 81,
#  'like': 82,
#  'study': 83,
#  'black': 84,
#  'theory': 85,
#  'sandwich': 86,
#  'interest': 87,
#  'orange': 88,
#  'many': 89,
#  'fat': 90,
#  'government': 91,
#  'ready': 92,
#  'move': 93,
#  'order': 94,
#  'argue': 95,
#  'good': 96,
#  'bad': 97,
#  'daughter': 98,
#  'yesterday': 99,
#  'toast': 100,
#  'snow': 101,
#  'write': 102,
#  'silly': 103,
#  'fine': 104,
#  'right': 105,
#  'cow': 106,
#  'how': 107,
#  'hair': 108,
#  'headache': 109,
#  'inform': 110,
#  'voice': 111,
#  'today': 112,
#  'alone': 113,
#  'wet': 114,
#  'vomit': 115,
#  'same': 116,
#  'add': 117,
#  'wow': 118,
#  'city': 119,
#  'class': 120,
#  'want': 121,
#  'water': 122,
#  'visit': 123,
#  'decide': 124,
#  'meet': 125,
#  'school': 126,
#  'pink': 127,
#  'pull': 128,
#  'africa': 129,
#  'australia': 130,
#  'balloon': 131,
#  'kiss': 132,
#  'near': 133,
#  'tiger': 134,
#  'week': 135,
#  'show': 136,
#  'decorate': 137,
#  'cat': 138,
#  'ball': 139,
#  'california': 140,
#  'weekend': 141,
#  'ago': 142,
#  'glasses': 143,
#  'animal': 144,
#  'halloween': 145,
#  'catch': 146,
#  'baby': 147,
#  'chat': 148,
#  'list': 149,
#  'outside': 150,
#  'careful': 151,
#  'lose': 152,
#  'shock': 153,
#  'stay': 154,
#  'problem': 155,
#  'first': 156,
#  'buy': 157,
#  'follow': 158,
#  'child': 159,
#  'dry': 160,
#  'dive': 161,
#  'dirty': 162,
#  'fast': 163,
#  'point': 164,
#  'improve': 165,
#  'necklace': 166,
#  'minute': 167,
#  'town': 168,
#  'fault': 169,
#  'great': 170,
#  'banana': 171,
#  'make': 172,
#  'carrot': 173,
#  'ugly': 174,
#  'new': 175,
#  'office': 176,
#  'party': 177,
#  'past': 178,
#  'practice': 179,
#  'sign': 180,
#  'president': 181,
#  'correct': 182,
#  'big': 183,
#  'country': 184,
#  'form': 185,
#  'upset': 186,
#  'train': 187,
#  'beard': 188,
#  'football': 189,
#  'future': 190,
#  'travel': 191,
#  'day': 192,
#  'crash': 193,
#  'drop': 194,
#  'hope': 195,
#  'finish': 196,
#  'now': 197,
#  'grammar': 198,
#  'girl': 199,
#  'hear': 200,
#  'hat': 201,
#  'can': 202,
#  'barely': 203,
#  'cancel': 204,
#  'choice': 205,
#  'dessert': 206,
#  'dollar': 207,
#  'enjoy': 208,
#  'blue': 209,
#  'all': 210,
#  'allergy': 211,
#  'demand': 212,
#  'develop': 213,
#  'ride': 214,
#  'russia': 215,
#  'join': 216,
#  'light': 217,
#  'mean': 218,
#  'cop': 219,
#  'cloud': 220,
#  'strawberry': 221,
#  'music': 222,
#  'pants': 223,
#  'awful': 224,
#  'bark': 225,
#  'beer': 226,
#  'bitter': 227,
#  'cake': 228,
#  'rob': 229,
#  'salt': 230,
#  'since': 231,
#  'small': 232,
#  'student': 233,
#  'tomato': 234,
#  'underwear': 235,
#  'exchange': 236,
#  'face': 237,
#  'front': 238,
#  'more': 239,
#  'christmas': 240,
#  'close': 241,
#  'discuss': 242,
#  'dress': 243,
#  'special': 244,
#  'helicopter': 245,
#  'history': 246,
#  'you': 247,
#  'approve': 248,
#  'arrive': 249,
#  'boy': 250,
#  'transfer': 251,
#  'weather': 252,
#  'accept': 253,
#  'allow': 254,
#  'heart': 255,
#  'bring': 256,
#  'cereal': 257,
#  'postpone': 258,
#  'come here': 259,
#  'late': 260,
#  'police': 261,
#  'shine': 262,
#  'sky': 263,
#  'again': 264,
#  'sunday': 265,
#  'test': 266,
#  'copy': 267,
#  'present': 268,
#  'one': 269,
#  'stink': 270,
#  'sunset': 271,
#  'east': 272,
#  'possible': 273,
#  'scared': 274,
#  'sad': 275,
#  'save': 276,
#  'farm': 277,
#  'humble': 278,
#  'internet': 279,
#  'match': 280,
#  'meat': 281,
#  'slow': 282,
#  'overwhelm': 283,
#  'presentation': 284,
#  'mirror': 285,
#  'miss': 286,
#  'onion': 287,
#  'idea': 288,
#  'important': 289,
#  'jealous': 290,
#  'disconnect': 291,
#  'potato': 292,
#  'lemon': 293,
#  'spin': 294,
#  'ear': 295,
#  'escape': 296,
#  'expensive': 297,
#  'find': 298,
#  'fly': 299,
#  'smart': 300,
#  'soft': 301,
#  'spray': 302,
#  'stress': 303,
#  'strong': 304,
#  'happy': 305,
#  'know': 306,
#  'sick': 307,
#  'teacher': 308,
#  'with': 309,
#  'choose': 310,
#  'cookie': 311,
#  'cut': 312,
#  'deep': 313,
#  'dentist': 314,
#  'down': 315,
#  'card': 316,
#  'scissors': 317,
#  'secret': 318,
#  'different': 319,
#  'learn': 320,
#  'rabbit': 321,
#  'group': 322,
#  'her': 323,
#  'tease': 324,
#  'thirsty': 325,
#  'watch': 326,
#  'straight': 327,
#  'temperature': 328,
#  'tent': 329,
#  'cafeteria': 330,
#  'vote': 331,
#  'wednesday': 332,
#  'west': 333,
#  'when': 334,
#  'word': 335,
#  'already': 336,
#  'analyze': 337,
#  'wife': 338,
#  'yellow': 339,
#  'backpack': 340,
#  'cook': 341,
#  'medicine': 342,
#  'paper': 343,
#  'boat': 344,
#  'wind': 345,
#  'purple': 346,
#  'time': 347,
#  'hearing': 348,
#  'brown': 349,
#  'wrong': 350,
#  'color': 351,
#  'blind': 352,
#  'bother': 353,
#  'bottom': 354,
#  'peaceful': 355,
#  'bottle': 356,
#  'boss': 357,
#  'take turns': 358,
#  'recent': 359,
#  'but': 360,
#  'jacket': 361,
#  'paint': 362,
#  'benefit': 363,
#  'expert': 364,
#  'forest': 365,
#  'frog': 366,
#  'goal': 367,
#  'golf': 368,
#  'wedding': 369,
#  'airplane': 370,
#  'also': 371,
#  'angry': 372,
#  'red': 373,
#  'structure': 374,
#  'elephant': 375,
#  'explain': 376,
#  'fight': 377,
#  'from': 378,
#  'car': 379,
#  'deer': 380,
#  'age': 381,
#  'chop': 382,
#  'christian': 383,
#  'cochlear implant': 384,
#  'sister': 385,
#  'sorry': 386,
#  'talk': 387,
#  'thank you': 388,
#  'bread': 389,
#  'dinner': 390,
#  'dinosaur': 391,
#  'discover': 392,
#  'educate': 393,
#  'niece': 394,
#  'north': 395,
#  'not': 396,
#  'off': 397,
#  'ok': 398,
#  'patient': 399,
#  'pay': 400,
#  'lettuce': 401,
#  'service': 402,
#  'stare': 403,
#  'store': 404,
#  'straw': 405,
#  'monkey': 406,
#  'motorcycle': 407,
#  'never': 408,
#  'pepper': 409,
#  'quick': 410,
#  'rehearse': 411,
#  'remove': 412,
#  'review': 413,
#  'get': 414,
#  'hospital': 415,
#  'japan': 416,
#  'king': 417,
#  'kitchen': 418,
#  'large': 419,
#  'think': 420,
#  'throw': 421,
#  'shape': 422,
#  'saturday': 423,
#  'flexible': 424,
#  'fun': 425,
#  'hour': 426,
#  'hurry': 427,
#  'kill': 428,
#  'law': 429,
#  'month': 430,
#  'napkin': 431,
#  'open': 432,
#  'perfect': 433,
#  'private': 434,
#  'procrastinate': 435,
#  'project': 436,
#  'marry': 437,
#  'linguistics': 438,
#  'middle': 439,
#  'disappear': 440,
#  'egg': 441,
#  'father': 442,
#  'flower': 443,
#  'friendly': 444,
#  'tomorrow': 445,
#  'lead': 446,
#  'memorize': 447,
#  'plus': 448,
#  'quiet': 449,
#  'rain': 450,
#  'research': 451,
#  'science': 452,
#  'sentence': 453,
#  'cheese': 454,
#  'crazy': 455,
#  'answer': 456,
#  'herself': 457,
#  'highway': 458,
#  'ice cream': 459,
#  'information': 460,
#  'snake': 461,
#  'soap': 462,
#  'star': 463,
#  'struggle': 464,
#  'stubborn': 465,
#  'surgery': 466,
#  'moon': 467,
#  'glass': 468,
#  'iran': 469,
#  'some': 470,
#  'south': 471,
#  'teach': 472,
#  'fancy': 473,
#  'finally': 474,
#  'fox': 475,
#  'fruit': 476,
#  'function': 477,
#  'hawaii': 478,
#  'adult': 479,
#  'after': 480,
#  'angel': 481,
#  'always': 482,
#  'back': 483,
#  'bake': 484,
#  'bath': 485,
#  'war': 486,
#  'where': 487,
#  'none': 488,
#  'plan': 489,
#  'please': 490,
#  'contact': 491,
#  'encourage': 492,
#  'evidence': 493,
#  'area': 494,
#  'art': 495,
#  'aunt': 496,
#  'awkward': 497,
#  'bacon': 498,
#  'belt': 499,
#  'represent': 500,
#  'result': 501,
#  'here': 502,
#  'house': 503,
#  'husband': 504,
#  'care': 505,
#  'carry': 506,
#  'chain': 507,
#  'character': 508,
#  'contribute': 509,
#  'dad': 510,
#  'describe': 511,
#  'dissolve': 512,
#  'canada': 513,
#  'cheap': 514,
#  'clean': 515,
#  'compare': 516,
#  'complex': 517,
#  'children': 518,
#  'drive': 519,
#  'god': 520,
#  'autumn': 521,
#  'beautiful': 522,
#  'brush': 523,
#  'depend': 524,
#  'desert': 525,
#  'doll': 526,
#  'easter': 527,
#  'egypt': 528,
#  'europe': 529,
#  'event': 530,
#  'caption': 531,
#  'restaurant': 532,
#  'a lot': 533,
#  'calculate': 534,
#  'about': 535,
#  'business': 536,
#  'swallow': 537,
#  'to': 538,
#  'translate': 539,
#  'up': 540,
#  'violin': 541,
#  'volunteer': 542,
#  'experience': 543,
#  'food': 544,
#  'freeze': 545,
#  'giraffe': 546,
#  'most': 547,
#  'beginning': 548,
#  'belief': 549,
#  'pig': 550,
#  'center': 551,
#  'old': 552,
#  'person': 553,
#  'remember': 554,
#  'share': 555,
#  'power': 556,
#  'sour': 557,
#  'spirit': 558,
#  'steal': 559,
#  'grandfather': 560,
#  'greece': 561,
#  'guitar': 562,
#  'invest': 563,
#  'lie': 564,
#  'feel': 565,
#  'raccoon': 566,
#  'really': 567,
#  'reason': 568,
#  'religion': 569,
#  'respect': 570,
#  'sell': 571,
#  'quit': 572,
#  'retire': 573,
#  'rise': 574,
#  'rough': 575,
#  'lobster': 576,
#  'love': 577,
#  'lucky': 578,
#  'measure': 579,
#  'microwave': 580,
#  'neighbor': 581,
#  'tired': 582,
#  'coffee': 583,
#  'college': 584,
#  'cute': 585,
#  'friend': 586,
#  'listen': 587,
#  'march': 588,
#  'math': 589,
#  'mom': 590,
#  'must': 591,
#  'negative': 592,
#  'nervous': 593,
#  'opinion': 594,
#  'pass': 595,
#  'pillow': 596,
#  'prepare': 597,
#  'themselves': 598,
#  'tuesday': 599,
#  'turkey': 600,
#  'university': 601,
#  'until': 602,
#  'weak': 603,
#  'smile': 604,
#  'sound': 605,
#  'stomach': 606,
#  'story': 607,
#  'strange': 608,
#  'sugar': 609,
#  'lecture': 610,
#  'limit': 611,
#  'home': 612,
#  'tea': 613,
#  'run': 614,
#  'bathroom': 615,
#  'document': 616,
#  'gas': 617,
#  'geography': 618,
#  'professional': 619,
#  'door': 620,
#  'green': 621,
#  'appear': 622,
#  'arm': 623,
#  'grandmother': 624,
#  'grapes': 625,
#  'guilty': 626,
#  'in': 627,
#  'independent': 628,
#  'summer': 629,
#  'chair': 630,
#  'obsess': 631,
#  'calm': 632,
#  'comfortable': 633,
#  'conflict': 634,
#  'destroy': 635,
#  'drawer': 636,
#  'drunk': 637,
#  'eagle': 638,
#  'asia': 639,
#  'ask': 640,
#  'attitude': 641,
#  'bald': 642,
#  'eat': 643,
#  'forget': 644,
#  'dance': 645,
#  'we': 646,
#  'without': 647,
#  'understand': 648,
#  'win': 649,
#  'afternoon': 650,
#  'third': 651,
#  'three': 652,
#  'tie': 653,
#  'topic': 654,
#  'tournament': 655,
#  'avoid': 656,
#  'bear': 657,
#  'believe': 658,
#  'bored': 659,
#  'box': 660,
#  'bracelet': 661,
#  'spell': 662,
#  'need': 663,
#  'spring': 664,
#  'silver': 665,
#  'siren': 666,
#  'skin': 667,
#  'borrow': 668,
#  'experiment': 669,
#  'fact': 670,
#  'feedback': 671,
#  'fold': 672,
#  'france': 673,
#  'butter': 674,
#  'candle': 675,
#  'comb': 676,
#  'deodorant': 677,
#  'diamond': 678,
#  'hamburger': 679,
#  'head': 680,
#  'impossible': 681,
#  'inside': 682,
#  'insurance': 683,
#  'arrest': 684,
#  'attract': 685,
#  'baseball': 686,
#  'bite': 687,
#  'blame': 688,
#  'body': 689,
#  'temple': 690,
#  'tender': 691,
#  'thailand': 692,
#  'tissue': 693,
#  'senior': 694,
#  'have': 695,
#  'knife': 696,
#  'read': 697,
#  'quote': 698,
#  'soup': 699,
#  'spain': 700,
#  'squirrel': 701,
#  'street': 702,
#  'strict': 703,
#  'lesson': 704,
#  'maybe': 705,
#  'mechanic': 706,
#  'sixteen': 707,
#  'sprint': 708,
#  'gossip': 709,
#  'world': 710,
#  'nose': 711,
#  'often': 712,
#  'operate': 713,
#  'program': 714,
#  'put': 715,
#  'price': 716,
#  'island': 717,
#  'suspect': 718,
#  'sweetheart': 719,
#  'therapy': 720,
#  'ticket': 721,
#  'top': 722,
#  'politics': 723,
#  'pound': 724,
#  'wallet': 725,
#  'weight': 726,
#  'whale': 727,
#  'over': 728,
#  'single': 729,
#  'queen': 730,
#  'radio': 731,
#  'rat': 732,
#  'require': 733,
#  'rest': 734,
#  'much': 735,
#  'neutral': 736,
#  'physician': 737,
#  'mix': 738,
#  'network': 739,
#  'nineteen': 740,
#  'wrap': 741,
#  'adapt': 742,
#  'agreement': 743,
#  'peach': 744,
#  'polite': 745,
#  'should': 746,
#  'skinny': 747,
#  'skirt': 748,
#  'prison': 749,
#  'push': 750,
#  'rule': 751,
#  'salad': 752,
#  'serious': 753,
#  'laptop': 754,
#  'lift': 755,
#  'lightning': 756,
#  'between': 757,
#  'infection': 758,
#  'bush': 759,
#  'cannot': 760,
#  'high': 761,
#  'hungry': 762,
#  'introduce': 763,
#  'lazy': 764,
#  'television': 765,
#  'together': 766,
#  'triangle': 767,
#  'seem': 768,
#  'my': 769,
#  'forever': 770,
#  'french fries': 771,
#  'eye': 772,
#  'fake': 773,
#  'flute': 774,
#  'dangerous': 775,
#  'witness': 776,
#  'wood': 777,
#  'across': 778,
#  'actor': 779,
#  'sculpture': 780,
#  'guess': 781,
#  'hammer': 782,
#  'disgust': 783,
#  'name': 784,
#  'dorm': 785,
#  'eighteen': 786,
#  'due': 787,
#  'constitution': 788,
#  'crab': 789,
#  'deduct': 790,
#  'ceiling': 791,
#  'cemetery': 792,
#  'choir': 793,
#  'come': 794,
#  'window': 795,
#  'below': 796,
#  'bet': 797,
#  'bicycle': 798,
#  'biology': 799,
#  'wash': 800,
#  'fail': 801,
#  'feed': 802,
#  'flag': 803,
#  'friday': 804,
#  'confront': 805,
#  'confused': 806,
#  'congress': 807,
#  'dull': 808,
#  'email': 809,
#  'end': 810,
#  'celebrate': 811,
#  'certificate': 812,
#  'chase': 813,
#  'apartment': 814,
#  'attention': 815,
#  'audience': 816,
#  'august': 817,
#  'away': 818,
#  'bully': 819,
#  'game': 820,
#  'live': 821,
#  'get up': 822,
#  'affect': 823,
#  'cracker': 824,
#  'curious': 825,
#  'curriculum': 826,
#  'diaper': 827,
#  'diarrhea': 828,
#  'divide': 829,
#  'building': 830,
#  'desk': 831,
#  'dictionary': 832,
#  'elevator': 833,
#  'angle': 834,
#  'apostrophe': 835,
#  'wide': 836,
#  'willing': 837,
#  'wonderful': 838,
#  'worse': 839,
#  'double': 840,
#  'doubt': 841,
#  'earth': 842,
#  'eight': 843,
#  'embarrass': 844,
#  'emotion': 845,
#  'community': 846,
#  'complain': 847,
#  'compromise': 848,
#  'cost': 849,
#  'action': 850,
#  'tooth': 851,
#  'tough': 852,
#  'trust': 853,
#  'while': 854,
#  'subtract': 855,
#  'expect': 856,
#  'bedroom': 857,
#  'both': 858,
#  'gather': 859,
#  'germany': 860,
#  'goat': 861,
#  'cause': 862,
#  'challenge': 863,
#  'chocolate': 864,
#  'continue': 865,
#  'curse': 866,
#  'surface': 867,
#  'switzerland': 868,
#  'tale': 869,
#  'terrible': 870,
#  'similar': 871,
#  'six': 872,
#  'sketch': 873,
#  'tree': 874,
#  'truck': 875,
#  'uncle': 876,
#  'vacation': 877,
#  'america': 878,
#  'honor': 879,
#  'if': 880,
#  'energy': 881,
#  'exact': 882,
#  'your': 883,
#  'slip': 884,
#  'snob': 885,
#  'specific': 886,
#  'steel': 887,
#  'rock': 888,
#  'land': 889,
#  'lesbian': 890,
#  'line': 891,
#  'lock': 892,
#  'loud': 893,
#  'lousy': 894,
#  'lunch': 895,
#  'recover': 896,
#  'relief': 897,
#  'grow': 898,
#  'gum': 899,
#  'seven': 900,
#  'she': 901,
#  'jewelry': 902,
#  'refuse': 903,
#  'divorce': 904,
#  'draw': 905,
#  'sit': 906,
#  'neck': 907,
#  'jesus': 908,
#  'keep': 909,
#  'keyboard': 910,
#  'soda': 911,
#  'there': 912,
#  'easy': 913,
#  'hard': 914,
#  'cough': 915,
#  'responsibility': 916,
#  'motivate': 917,
#  'path': 918,
#  'physics': 919,
#  'popular': 920,
#  'pray': 921,
#  'predict': 922,
#  'print': 923,
#  'printer': 924,
#  'protect': 925,
#  'provide': 926,
#  'psychology': 927,
#  'machine': 928,
#  'monday': 929,
#  'picture': 930,
#  'poor': 931,
#  'pocket': 932,
#  'proof': 933,
#  'purpose': 934,
#  'race': 935,
#  'mexico': 936,
#  'multiply': 937,
#  'myself': 938,
#  'people': 939,
#  'puzzled': 940,
#  'revenge': 941,
#  'rich': 942,
#  'rude': 943,
#  'parade': 944,
#  'philosophy': 945,
#  'policy': 946,
#  'nothing': 947,
#  'offer': 948,
#  'only': 949,
#  'key': 950,
#  'label': 951,
#  'leaf': 952,
#  'lend': 953,
#  'second': 954,
#  'senate': 955,
#  'separate': 956,
#  'shrimp': 957,
#  'shy': 958,
#  'situation': 959,
#  'publish': 960,
#  'punish': 961,
#  'meeting': 962,
#  'morning': 963,
#  'lonely': 964,
#  'maximum': 965,
#  'health': 966,
#  'stairs': 967,
#  'suggest': 968,
#  'sun': 969,
#  'support': 970,
#  'surprise': 971,
#  'sweater': 972,
#  'say': 973,
#  'scotland': 974,
#  'happen': 975,
#  'hit': 976,
#  'investigate': 977,
#  'last year': 978,
#  'screwdriver': 979,
#  'influence': 980,
#  'interesting': 981,
#  'notice': 982,
#  'birthday': 983,
#  'floor': 984,
#  'church': 985,
#  'cup': 986,
#  'taste': 987,
#  'team': 988,
#  'telephone': 989,
#  'tennis': 990,
#  'slave': 991,
#  'socks': 992,
#  'solid': 993,
#  'spider': 994,
#  'jump': 995,
#  'money': 996,
#  'general': 997,
#  'ghost': 998,
#  'give up': 999,
#  ...}

# %%
features_df['gloss_indx'] = features_df.gloss.map(classes_dict)

# %%
features_df
# Out:
#             gloss video_id                                                url  \
# index
# 0            book    69241       http://aslbricks.org/New/ASL-Videos/book.mp4
# 1            book    07069  https://signstock.blob.core.windows.net/signsc...
# 2            book    07068  https://s3-us-west-1.amazonaws.com/files.start...
# 3            book    07070  https://media.asldeafined.com/vocabulary/14666...
# 4            book    07099     http://www.aslsearch.com/signs/videos/book.mp4
# ...           ...      ...                                                ...
# 11975  wheelchair    63047  https://www.signingsavvy.com/signs/mp4/5/5233.mp4
# 11976  wheelchair    63050  http://www.aslsearch.com/signs/videos/wheelcha...
# 11977     whistle    63186  https://media.spreadthesign.com/video/mp4/13/9...
# 11978     whistle    63188  https://www.signingsavvy.com/signs/mp4/9/9961.mp4
# 11979     whistle    63190  http://www.aslsearch.com/signs/videos/whistle.mp4
#
#        gloss_indx
# index
# 0            1062
# 1            1062
# 2            1062
# 3            1062
# 4            1062
# ...           ...
# 11975        1581
# 11976        1581
# 11977        1917
# 11978        1917
# 11979        1917
#
# [11980 rows x 4 columns]

# %% [markdown]
# > *let's initialize some constants*

# %%
# Specify the hight and width each video frame will be resized in our dataset.
IMAGE_HEIGHT, IMAGE_WIDTH = 64, 64

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 20

# Specify the directory containing the dataset.
DATASET_DIR = "wlasl-processed/videos/"

# Specify the list containing the names of the classes used for training.
CLASSES_LIST = all_classes

# %% [markdown]
# **Note:** *The **`IMAGE_HEIGHT`**, **`IMAGE_WIDTH`** and **`SEQUENCE_LENGTH`** constants can be increased for better results, although increasing the sequence length is only effective to a certain point, and increasing the values will result in the process being more computationally expensive.*

# %%
def get_index_of_video(vd_id):
    i = 0
    for item in features_df["video_id"]:
        if item == vd_id:
            break
        i = i+1
    return i

# %%
# Create a Matplotlib figure and specify the size of the figure
plt.figure(figsize=(20, 20))

# Get the names of all classes/categories in UCF50
all_classes_names = os.listdir(DATASET_DIR)

# generate a list of 20 random values. The values will be between 0-50 where 50 is the
# total number of classes in the dataset
random_range = random.sample(range(len(all_classes_names)), 20)

# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):

    # Retrieve the list of all the video files present in the randomly selected Class Directory
    video_files_names_list = os.listdir(DATASET_DIR)

    #Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Retrieve a Class Name using the Random Index.
    idx = get_index_of_video(selected_video_file_name.split(".")[0])
    selected_class_Name = features_df.iloc[idx].gloss

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'{DATASET_DIR}{selected_video_file_name}')

    # Read the first frame of the video file
    _, bgr_frame = video_reader.read()

    # release the video object
    video_reader.release()

    #  convert the frame from VGR into RBG format.
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    # Display the frame
    plt.subplot(5, 4, counter); plt.imshow(rgb_frame);plt.axis('off')

# %% [markdown]
# ## **<font style="color:#112B3C">Preprocess the Dataset</font>**
#
# Next, we will perform some preprocessing on the dataset. First, we will read the video files from the dataset and resize the frames of the videos to a fixed width and height, to reduce the computations and normalized the data to range `[0-1]` by dividing the pixel values with `255`, which makes convergence faster while training the network.

# %% [markdown]
# ### **<font style="color:#205375">Create a Function to Extract, Resize & Normalize Frames</font>**
#
# We will create a function **`frames_extraction()`** that will create a list containing the resized and normalized frames of a video whose path is passed to it as an argument. The function will read the video file frame by frame, although not all frames are added to the list as we will only need an evenly distributed sequence length of frames.

# %%
def frames_extraction(video_path):
    """
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
    video_path: The path of the video in the disk, whose frames are to be extracted.

    Returns:
    frames_list: A list containing the resized and normalized frames of the video.
    """

    # Declare a list to store video frames.
    frames_list = []

    # Read the video File using the videoCapture object.
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video frames:
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video.
        success, frame = video_reader.read()

        # check if the video frame is not successfully read the break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies wetween 0 and 1
        normalized_frame = resized_frame / 255

        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)

    # Release the VideoCapture object.
    video_reader.release()

    # return the frames list.
    return frames_list

# %% [markdown]
# ### **<font style="color:#205375">Create a Function for Dataset Creation</font>**
#
# Now we will create a function **`create_dataset()`** that will iterate through all the video located in the **`DATASET_DIR`** constant and will call the function  **`frame_extraction()`** on every video file and return the frames (**`features`**), class index ( **`labels`**), and video file path (**`video_files_paths`**).

# %%
def create_dataset():
    """
    This function will extract the data of the videos and create the required dataset.
    Retuns:
    features: A list containing the extracted frames of the videos.
    labels :  A list containing the indexes of the classes associated with the video
    video_files_paths :  A list containing the paths of the videos in the disk.
    """

    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []


    # Get the list of video files present in the specific class name directory.
    files_list = os.listdir(DATASET_DIR)
    count = 0
    for file_name in files_list:

        # Display the name of the video whose data is being extracted and its number in iterations
        print(f"Extracting Data of file: {file_name}, number: {count}")

        # Get the complete video path.
        video_file_path = os.path.join(DATASET_DIR, file_name)

        # Extract the frames of the video file.
        frames = frames_extraction(video_file_path)

        # check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
        # So ignore the videos having less than the SEQUENCE_LENGTH.
        if len(frames) == SEQUENCE_LENGTH:

            # Append the data to their repective list
            features.append(frames)
            # get the video's class name
            idx = get_index_of_video(file_name.split(".")[0])
            class_index = features_df.iloc[idx].gloss_indx
            labels.append(class_index)
            video_files_paths.append(video_file_path)
            count = count +1
            if count > 1000:
                break

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)

    # Return the frames, class_index and video_file_path
    return features, labels, video_files_paths

# %% [markdown]
# Now we will utilize the function **`create_dataset()`** created above to extract the
pickle.dump(features, output)
output.close()

# %%
import pprint, pickle

pkl_file = open('features.pkl', 'rb')

data1 = pickle.load(pkl_file)
pprint.pprint(data1)

pkl_file.close()
# Out:
# array([[[[[0.21568627, 0.2       , 0.02745098],
#           [0.21960784, 0.20392157, 0.03137255],
#           [0.23921569, 0.21960784, 0.03529412],
#           ...,
#           [0.20392157, 0.19607843, 0.02745098],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17647059, 0.01960784]],
#
#          [[0.21568627, 0.2       , 0.02745098],
#           [0.21960784, 0.20392157, 0.03137255],
#           [0.24313725, 0.22352941, 0.03921569],
#           ...,
#           [0.20392157, 0.19607843, 0.02745098],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17647059, 0.01960784]],
#
#          [[0.21960784, 0.20392157, 0.03137255],
#           [0.22352941, 0.20784314, 0.03529412],
#           [0.24313725, 0.22352941, 0.03921569],
#           ...,
#           [0.20392157, 0.19607843, 0.02745098],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17647059, 0.01960784]],
#
#          ...,
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29803922, 0.2745098 , 0.04705882],
#           [0.31764706, 0.2745098 , 0.04313725],
#           ...,
#           [0.25098039, 0.23137255, 0.03921569],
#           [0.23529412, 0.22352941, 0.03921569],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29411765, 0.27058824, 0.04313725],
#           [0.30588235, 0.27843137, 0.03529412],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23529412, 0.22352941, 0.03137255],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29411765, 0.27058824, 0.04313725],
#           [0.30588235, 0.2745098 , 0.03921569],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23529412, 0.22352941, 0.03137255],
#           [0.22352941, 0.21176471, 0.02745098]]],
#
#
#         [[[0.21568627, 0.2       , 0.02745098],
#           [0.22745098, 0.20784314, 0.02352941],
#           [0.23921569, 0.21960784, 0.03529412],
#           ...,
#           [0.21176471, 0.19215686, 0.02745098],
#           [0.2       , 0.18431373, 0.03529412],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          [[0.21960784, 0.20392157, 0.03137255],
#           [0.23137255, 0.21176471, 0.02745098],
#           [0.24313725, 0.22352941, 0.03921569],
#           ...,
#           [0.21176471, 0.19215686, 0.02745098],
#           [0.2       , 0.18431373, 0.03529412],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          [[0.21960784, 0.20392157, 0.03137255],
#           [0.23921569, 0.21960784, 0.03529412],
#           [0.24705882, 0.22745098, 0.04313725],
#           ...,
#           [0.21176471, 0.19215686, 0.02745098],
#           [0.2       , 0.18431373, 0.03529412],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          ...,
#
#          [[0.29019608, 0.26666667, 0.03921569],
#           [0.29803922, 0.2745098 , 0.03921569],
#           [0.30196078, 0.28235294, 0.03921569],
#           ...,
#           [0.25098039, 0.23137255, 0.03921569],
#           [0.23529412, 0.22352941, 0.03921569],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.25882353, 0.05098039],
#           [0.29411765, 0.26666667, 0.05098039],
#           [0.30980392, 0.27843137, 0.04313725],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23529412, 0.22352941, 0.03137255],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.25882353, 0.05098039],
#           [0.29411765, 0.26666667, 0.05098039],
#           [0.30588235, 0.2745098 , 0.04705882],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23529412, 0.22352941, 0.03137255],
#           [0.22352941, 0.21176471, 0.02745098]]],
#
#
#         [[[0.21568627, 0.2       , 0.02745098],
#           [0.23137255, 0.21176471, 0.02745098],
#           [0.23137255, 0.21960784, 0.02745098],
#           ...,
#           [0.20784314, 0.18431373, 0.03137255],
#           [0.2       , 0.18431373, 0.03529412],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          [[0.21960784, 0.20392157, 0.03137255],
#           [0.23137255, 0.21176471, 0.02745098],
#           [0.23529412, 0.22352941, 0.03137255],
#           ...,
#           [0.20784314, 0.18431373, 0.03137255],
#           [0.2       , 0.18431373, 0.03529412],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          [[0.21960784, 0.20392157, 0.03137255],
#           [0.23921569, 0.21960784, 0.03529412],
#           [0.23921569, 0.22745098, 0.03529412],
#           ...,
#           [0.21176471, 0.19215686, 0.02745098],
#           [0.20784314, 0.18039216, 0.03529412],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          ...,
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29803922, 0.2745098 , 0.04705882],
#           [0.30196078, 0.28235294, 0.03921569],
#           ...,
#           [0.23921569, 0.22745098, 0.03529412],
#           [0.23529412, 0.22352941, 0.03921569],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29411765, 0.2627451 , 0.05490196],
#           [0.30588235, 0.2745098 , 0.04705882],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23529412, 0.22352941, 0.03137255],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29411765, 0.2627451 , 0.05490196],
#           [0.29803922, 0.2745098 , 0.04705882],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23529412, 0.22352941, 0.03137255],
#           [0.22352941, 0.21176471, 0.02745098]]],
#
#
#         ...,
#
#
#         [[[0.22745098, 0.20392157, 0.03137255],
#           [0.23137255, 0.21176471, 0.02745098],
#           [0.24705882, 0.21960784, 0.02745098],
#           ...,
#           [0.2       , 0.18823529, 0.03137255],
#           [0.2       , 0.18431373, 0.02745098],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          [[0.22745098, 0.20392157, 0.03137255],
#           [0.23137255, 0.21176471, 0.02745098],
#           [0.25098039, 0.22352941, 0.03137255],
#           ...,
#           [0.20392157, 0.19215686, 0.03529412],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          [[0.22745098, 0.20392157, 0.03137255],
#           [0.23921569, 0.21960784, 0.03529412],
#           [0.25490196, 0.22745098, 0.03529412],
#           ...,
#           [0.21176471, 0.19607843, 0.02352941],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          ...,
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29803922, 0.2745098 , 0.04705882],
#           [0.30196078, 0.27843137, 0.04313725],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23137255, 0.21960784, 0.03529412],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29411765, 0.27058824, 0.04313725],
#           [0.29803922, 0.2745098 , 0.03921569],
#           ...,
#           [0.24705882, 0.23137255, 0.03137255],
#           [0.23137255, 0.21960784, 0.02745098],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29411765, 0.27058824, 0.04313725],
#           [0.29803922, 0.2745098 , 0.04705882],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23137255, 0.21960784, 0.02745098],
#           [0.22352941, 0.21176471, 0.02745098]]],
#
#
#         [[[0.22745098, 0.20392157, 0.03137255],
#           [0.22745098, 0.20392157, 0.03137255],
#           [0.23137255, 0.21960784, 0.03529412],
#           ...,
#           [0.2       , 0.18823529, 0.03137255],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          [[0.22745098, 0.20392157, 0.03137255],
#           [0.23137255, 0.20784314, 0.03529412],
#           [0.23529412, 0.22352941, 0.03921569],
#           ...,
#           [0.20392157, 0.19215686, 0.03529412],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          [[0.22745098, 0.20392157, 0.03137255],
#           [0.23921569, 0.21176471, 0.03921569],
#           [0.23921569, 0.22745098, 0.04313725],
#           ...,
#           [0.21176471, 0.19607843, 0.02352941],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          ...,
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29803922, 0.2745098 , 0.04705882],
#           [0.30196078, 0.27843137, 0.04313725],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23529412, 0.22352941, 0.03921569],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29411765, 0.27058824, 0.04313725],
#           [0.29803922, 0.2745098 , 0.03921569],
#           ...,
#           [0.24705882, 0.23137255, 0.03137255],
#           [0.23529412, 0.22352941, 0.03137255],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29411765, 0.27058824, 0.04313725],
#           [0.29803922, 0.2745098 , 0.03921569],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23529412, 0.22352941, 0.03137255],
#           [0.22352941, 0.21176471, 0.02745098]]],
#
#
#         [[[0.22745098, 0.20392157, 0.03137255],
#           [0.22745098, 0.20392157, 0.03137255],
#           [0.23137255, 0.21960784, 0.03529412],
#           ...,
#           [0.2       , 0.18823529, 0.03137255],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          [[0.22745098, 0.20392157, 0.03137255],
#           [0.23137255, 0.20784314, 0.03529412],
#           [0.23529412, 0.22352941, 0.03921569],
#           ...,
#           [0.20392157, 0.19215686, 0.03529412],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          [[0.22745098, 0.20392157, 0.03137255],
#           [0.23921569, 0.21176471, 0.03921569],
#           [0.23921569, 0.22745098, 0.04313725],
#           ...,
#           [0.21176471, 0.19607843, 0.02352941],
#           [0.2       , 0.18823529, 0.03137255],
#           [0.18823529, 0.17254902, 0.02352941]],
#
#          ...,
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29803922, 0.2745098 , 0.04705882],
#           [0.30196078, 0.27843137, 0.04313725],
#           ...,
#           [0.24705882, 0.23137255, 0.03137255],
#           [0.23529412, 0.22352941, 0.03921569],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29411765, 0.27058824, 0.04313725],
#           [0.29803922, 0.2745098 , 0.03921569],
#           ...,
#           [0.24705882, 0.22745098, 0.03529412],
#           [0.23529412, 0.22352941, 0.03137255],
#           [0.22352941, 0.21176471, 0.02745098]],
#
#          [[0.29019608, 0.2627451 , 0.04705882],
#           [0.29411765, 0.27058824, 0.04313725],
#           [0.29803922, 0.2745098 , 0.03921569],
#           ...,
#           [0.24705882, 0.22745098, 0.04313725],
#           [0.23529412, 0.22352941, 0.03137255],
#           [0.22352941, 0.21176471, 0.02745098]]]],
#
#
#
#        [[[[0.4745098 , 0.64313725, 0.35686275],
#           [0.48627451, 0.65490196, 0.36862745],
#           [0.50196078, 0.67058824, 0.38431373],
#           ...,
#           [0.49019608, 0.65882353, 0.37254902],
#           [0.4627451 , 0.63529412, 0.36078431],
#           [0.46666667, 0.63921569, 0.36470588]],
#
#          [[0.48627451, 0.62352941, 0.34509804],
#           [0.50196078, 0.63921569, 0.36078431],
#           [0.48627451, 0.64313725, 0.36078431],
#           ...,
#           [0.47058824, 0.63921569, 0.35294118],
#           [0.45882353, 0.63921569, 0.34509804],
#           [0.44705882, 0.62745098, 0.33333333]],
#
#          [[0.47843137, 0.63921569, 0.34901961],
#           [0.47058824, 0.63137255, 0.34117647],
#           [0.4745098 , 0.63921569, 0.3372549 ],
#           ...,
#           [0.48235294, 0.65882353, 0.35294118],
#           [0.45882353, 0.63529412, 0.34901961],
#           [0.45490196, 0.63137255, 0.34509804]],
#
#          ...,
#
#          [[0.34901961, 0.45098039, 0.14117647],
#           [0.34117647, 0.44313725, 0.13333333],
#           [0.33333333, 0.45882353, 0.1372549 ],
#           ...,
#           [0.37254902, 0.49411765, 0.21568627],
#           [0.36862745, 0.50196078, 0.21568627],
#           [0.36470588, 0.49803922, 0.21176471]],
#
#          [[0.32941176, 0.44313725, 0.13333333],
#           [0.3372549 , 0.45098039, 0.14117647],
#           [0.32941176, 0.4745098 , 0.14901961],
#           ...,
#           [0.36862745, 0.50196078, 0.19215686],
#           [0.36078431, 0.49411765, 0.20784314],
#           [0.35294118, 0.48627451, 0.2       ]],
#
#          [[0.33333333, 0.44705882, 0.1372549 ],
#           [0.3254902 , 0.43921569, 0.12941176],
#           [0.32156863, 0.45490196, 0.14117647],
#           ...,
#           [0.36470588, 0.49411765, 0.2       ],
#           [0.34901961, 0.48235294, 0.19607843],
#           [0.34117647, 0.4745098 , 0.18823529]]],
#
#
#         [[[0.49411765, 0.62352941, 0.36470588],
#           [0.50196078, 0.65490196, 0.38431373],
#           [0.50588235, 0.6745098 , 0.38823529],
#           ...,
#           [0.49019608, 0.65882353, 0.37254902],
#           [0.46666667, 0.63921569, 0.34509804],
#           [0.47843137, 0.64313725, 0.36862745]],
#
#          [[0.49411765, 0.61960784, 0.35294118],
#           [0.49019608, 0.64705882, 0.34509804],
#           [0.49411765, 0.65882353, 0.35686275],
#           ...,
#           [0.4745098 , 0.64313725, 0.35686275],
#           [0.46666667, 0.64313725, 0.3372549 ],
#           [0.45098039, 0.62352941, 0.32941176]],
#
#          [[0.48627451, 0.63529412, 0.35294118],
#           [0.4745098 , 0.63137255, 0.34901961],
#           [0.47058824, 0.64705882, 0.34117647],
#           ...,
#           [0.49411765, 0.65882353, 0.35686275],
#           [0.4627451 , 0.63529412, 0.34117647],
#           [0.45882353, 0.63921569, 0.34509804]],
#
#          ...,
#
#          [[0.32941176, 0.45098039, 0.14509804],
#           [0.33333333, 0.45098039, 0.12941176],
#           [0.31764706, 0.45882353, 0.14509804],
#           ...,
#           [0.38039216, 0.50588235, 0.21960784],
#           [0.37647059, 0.50196078, 0.21568627],
#           [0.36470588, 0.50196078, 0.20392157]],
#
#          [[0.32941176, 0.44313725, 0.1372549 ],
#           [0.3372549 , 0.45882353, 0.14901961],
#           [0.34117647, 0.47058824, 0.14117647],
#           ...,
#           [0.36862745, 0.49411765, 0.20784314],
#           [0.36078431, 0.49411765, 0.20784314],
#           [0.35294118, 0.47843137, 0.19215686]],
#
#          [[0.3254902 , 0.44705882, 0.14117647],
#           [0.32941176, 0.44705882, 0.1254902 ],
#           [0.32941176, 0.45490196, 0.13333333],
#           ...,
#           [0.36470588, 0.49019608, 0.20392157],
#           [0.36078431, 0.49411765, 0.20784314],
#           [0.34901961, 0.48235294, 0.19607843]]],
#
#
#         [[[0.47843137, 0.62352941, 0.35294118],
#           [0.49411765, 0.64705882, 0.37647059],
#           [0.48235294, 0.6627451 , 0.38823529],
#           ...,
#           [0.48627451, 0.6627451 , 0.37647059],
#           [0.47058824, 0.65098039, 0.33333333],
#           [0.47058824, 0.64313725, 0.34901961]],
#
#          [[0.47843137, 0.62352941, 0.35294118],
#           [0.48235294, 0.63137255, 0.36862745],
#           [0.49803922, 0.65882353, 0.36862745],
#           ...,
#           [0.46666667, 0.64705882, 0.35294118],
#           [0.46666667, 0.64705882, 0.32941176],
#           [0.46666667, 0.63921569, 0.34509804]],
#
#          [[0.48627451, 0.63137255, 0.36078431],
#           [0.48235294, 0.62745098, 0.35686275],
#           [0.47843137, 0.64705882, 0.33333333],
#           ...,
#           [0.49411765, 0.67843137, 0.37254902],
#           [0.45490196, 0.63529412, 0.34117647],
#           [0.45098039, 0.63137255, 0.3372549 ]],
#
#          ...,
#
#          [[0.3254902 , 0.44705882, 0.1372549 ],
#           [0.31372549, 0.43529412, 0.1254902 ],
#           [0.3372549 , 0.45882353, 0.14901961],
#           ...,
#           [0.37647059, 0.50196078, 0.21568627],
#           [0.37254902, 0.49803922, 0.21176471],
#           [0.37254902, 0.49803922, 0.21176471]],
#
#          [[0.32156863, 0.44313725, 0.13333333],
#           [0.33333333, 0.45098039, 0.15686275],
#           [0.32941176, 0.4627451 , 0.14901961],
#           ...,
#           [0.36078431, 0.49411765, 0.20784314],
#           [0.36078431, 0.49411765, 0.20784314],
#           [0.35686275, 0.49019608, 0.20392157]],
#
#          [[0.32156863, 0.43921569, 0.14509804],
#           [0.32156863, 0.44313725, 0.13333333],
#           [0.31764706, 0.45098039, 0.1372549 ],
#           ...,
#           [0.34901961, 0.47843137, 0.2       ],
#           [0.36470588, 0.49803922, 0.21176471],
#           [0.34509804, 0.47843137, 0.19215686]]],
#
#
#         ...,
#
#
#         [[[0.49411765, 0.61960784, 0.33333333],
#           [0.5254902 , 0.65490196, 0.35686275],
#           [0.52156863, 0.67058824, 0.36078431],
#           ...,
#           [0.50980392, 0.65882353, 0.34901961],
#           [0.49803922, 0.64705882, 0.3372549 ],
#           [0.50196078, 0.65098039, 0.34117647]],
#
#          [[0.49411765, 0.61960784, 0.33333333],
#           [0.51764706, 0.64705882, 0.34901961],
#           [0.50196078, 0.65098039, 0.34117647],
#           ...,
#           [0.49803922, 0.64313725, 0.34509804],
#           [0.48627451, 0.63529412, 0.3254902 ],
#           [0.47843137, 0.62745098, 0.31764706]],
#
#          [[0.49411765, 0.63529412, 0.32156863],
#           [0.49411765, 0.63529412, 0.32156863],
#           [0.49803922, 0.65098039, 0.3254902 ],
#           ...,
#           [0.49803922, 0.6627451 , 0.33333333],
#           [0.4745098 , 0.64313725, 0.3254902 ],
#           [0.4745098 , 0.64313725, 0.3254902 ]],
#
#          ...,
#
#          [[0.35686275, 0.45490196, 0.12941176],
#           [0.34901961, 0.44705882, 0.12156863],
#           [0.36078431, 0.45882353, 0.13333333],
#           ...,
#           [0.39215686, 0.50588235, 0.2       ],
#           [0.39215686, 0.50588235, 0.2       ],
#           [0.38823529, 0.50196078, 0.19607843]],
#
#          [[0.35294118, 0.44705882, 0.12941176],
#           [0.35686275, 0.45098039, 0.13333333],
#           [0.36470588, 0.4627451 , 0.1372549 ],
#           ...,
#           [0.39607843, 0.49803922, 0.19215686],
#           [0.4       , 0.50196078, 0.19607843],
#           [0.39215686, 0.49411765, 0.18823529]],
#
#          [[0.34509804, 0.43921569, 0.12156863],
#           [0.34509804, 0.43921569, 0.12156863],
#           [0.35294118, 0.45098039, 0.1254902 ],
#           ...,
#           [0.39215686, 0.49411765, 0.18823529],
#           [0.39215686, 0.49411765, 0.18823529],
#           [0.38039216, 0.48235294, 0.17647059]]],
#
#
#         [[[0.49411765, 0.61960784, 0.33333333],
#           [0.5254902 , 0.65098039, 0.36470588],
#           [0.50980392, 0.66666667, 0.37647059],
#           ...,
#           [0.50980392, 0.67058824, 0.35686275],
#           [0.49411765, 0.64313725, 0.33333333],
#           [0.50196078, 0.65098039, 0.34117647]],
#
#          [[0.49411765, 0.61960784, 0.33333333],
#           [0.49803922, 0.64313725, 0.34509804],
#           [0.49411765, 0.65490196, 0.34117647],
#           ...,
#           [0.48627451, 0.64313725, 0.34117647],
#           [0.47843137, 0.62745098, 0.31764706],
#           [0.49019608, 0.63921569, 0.32941176]],
#
#          [[0.49411765, 0.63529412, 0.3254902 ],
#           [0.49411765, 0.63529412, 0.3254902 ],
#           [0.50196078, 0.64705882, 0.32156863],
#           ...,
#           [0.50980392, 0.65490196, 0.32941176],
#           [0.48235294, 0.64313725, 0.32941176],
#           [0.47843137, 0.63921569, 0.3254902 ]],
#
#          ...,
#
#          [[0.35686275, 0.45490196, 0.12941176],
#           [0.34509804, 0.44313725, 0.11764706],
#           [0.36078431, 0.45490196, 0.1372549 ],
#           ...,
#           [0.40392157, 0.50588235, 0.19607843],
#           [0.39215686, 0.50588235, 0.2       ],
#           [0.38823529, 0.50196078, 0.19607843]],
#
#          [[0.35686275, 0.44705882, 0.12156863],
#           [0.36078431, 0.45098039, 0.1254902 ],
#           [0.37254902, 0.46666667, 0.12941176],
#           ...,
#           [0.4       , 0.49803922, 0.20392157],
#           [0.4       , 0.50196078, 0.19607843],
#           [0.39215686, 0.49411765, 0.18823529]],
#
#          [[0.35294118, 0.44313725, 0.11764706],
#           [0.35294118, 0.44313725, 0.11764706],
#           [0.35686275, 0.45098039, 0.11372549],
#           ...,
#           [0.39607843, 0.49411765, 0.2       ],
#           [0.39215686, 0.49411765, 0.18823529],
#           [0.38431373, 0.48627451, 0.18039216]]],
#
#
#         [[[0.49411765, 0.61960784, 0.33333333],
#           [0.51764706, 0.65098039, 0.36470588],
#           [0.50980392, 0.67058824, 0.38039216],
#           ...,
#           [0.50980392, 0.67058824, 0.35686275],
#           [0.48627451, 0.63529412, 0.3254902 ],
#           [0.50196078, 0.65098039, 0.34117647]],
#
#          [[0.49411765, 0.61960784, 0.33333333],
#           [0.50196078, 0.64705882, 0.34901961],
#           [0.49803922, 0.65882353, 0.34509804],
#           ...,
#           [0.49019608, 0.64705882, 0.34509804],
#           [0.47843137, 0.62745098, 0.31764706],
#           [0.49019608, 0.63921569, 0.32941176]],
#
#          [[0.49411765, 0.63529412, 0.3254902 ],
#           [0.49411765, 0.63529412, 0.3254902 ],
#           [0.50196078, 0.64705882, 0.32156863],
#           ...,
#           [0.51372549, 0.65882353, 0.33333333],
#           [0.47843137, 0.63921569, 0.3254902 ],
#           [0.47843137, 0.63921569, 0.3254902 ]],
#
#          ...,
#
#          [[0.35686275, 0.45490196, 0.12941176],
#           [0.34509804, 0.44313725, 0.11764706],
#           [0.35686275, 0.45098039, 0.13333333],
#           ...,
#           [0.40392157, 0.50588235, 0.19607843],
#           [0.4       , 0.50196078, 0.19607843],
#           [0.39215686, 0.49411765, 0.18823529]],
#
#          [[0.35686275, 0.44705882, 0.12156863],
#           [0.36078431, 0.45098039, 0.1254902 ],
#           [0.35686275, 0.4627451 , 0.14117647],
#           ...,
#           [0.39215686, 0.49019608, 0.19607843],
#           [0.4       , 0.50196078, 0.19607843],
#           [0.39215686, 0.49411765, 0.18823529]],
#
#          [[0.35294118, 0.44313725, 0.11764706],
#           [0.35294118, 0.44313725, 0.11764706],
#           [0.34117647, 0.44705882, 0.1254902 ],
#           ...,
#           [0.39607843, 0.49411765, 0.2       ],
#           [0.39215686, 0.49411765, 0.18823529],
#           [0.38431373, 0.48627451, 0.18039216]]]],
#
#
#
#        [[[[0.3254902 , 0.44313725, 0.78039216],
#           [0.30196078, 0.41568627, 0.76470588],
#           [0.30196078, 0.41568627, 0.79215686],
#           ...,
#           [0.23921569, 0.36470588, 0.68235294],
#           [0.23529412, 0.35686275, 0.69411765],
#           [0.23921569, 0.34117647, 0.69411765]],
#
#          [[0.32156863, 0.43921569, 0.78039216],
#           [0.30980392, 0.42745098, 0.76470588],
#           [0.29019608, 0.40784314, 0.77254902],
#           ...,
#           [0.24313725, 0.36862745, 0.68627451],
#           [0.23529412, 0.36078431, 0.69803922],
#           [0.24313725, 0.35686275, 0.70588235]],
#
#          [[0.30588235, 0.42745098, 0.77647059],
#           [0.30196078, 0.42745098, 0.76470588],
#           [0.28235294, 0.40784314, 0.77254902],
#           ...,
#           [0.23921569, 0.34901961, 0.68235294],
#           [0.22745098, 0.36078431, 0.69803922],
#           [0.23137255, 0.36862745, 0.69803922]],
#
#          ...,
#
#          [[0.21960784, 0.32156863, 0.65490196],
#           [0.2       , 0.30588235, 0.64705882],
#           [0.2       , 0.30196078, 0.63529412],
#           ...,
#           [0.15294118, 0.25490196, 0.56078431],
#           [0.15294118, 0.2627451 , 0.56862745],
#           [0.16470588, 0.28235294, 0.58823529]],
#
#          [[0.23137255, 0.33333333, 0.66666667],
#           [0.19607843, 0.30588235, 0.66666667],
#           [0.19215686, 0.29411765, 0.64705882],
#           ...,
#           [0.14509804, 0.25882353, 0.55294118],
#           [0.14117647, 0.25490196, 0.57254902],
#           [0.15686275, 0.27843137, 0.57254902]],
#
#          [[0.23921569, 0.34117647, 0.6745098 ],
#           [0.2       , 0.30980392, 0.67058824],
#           [0.19607843, 0.29803922, 0.65098039],
#           ...,
#           [0.15294118, 0.26666667, 0.56078431],
#           [0.14509804, 0.25882353, 0.57647059],
#           [0.16078431, 0.28235294, 0.57647059]]],
#
#
#         [[[0.31764706, 0.45098039, 0.76862745],
#           [0.29411765, 0.41960784, 0.75294118],
#           [0.29411765, 0.41960784, 0.78431373],
#           ...,
#           [0.23921569, 0.36862745, 0.67058824],
#           [0.23529412, 0.36078431, 0.69019608],
#           [0.23921569, 0.34509804, 0.68627451]],
#
#          [[0.31764706, 0.44705882, 0.76862745],
#           [0.30196078, 0.43137255, 0.76078431],
#           [0.28235294, 0.40784314, 0.76862745],
#           ...,
#           [0.24313725, 0.37254902, 0.6745098 ],
#           [0.23529412, 0.36470588, 0.69411765],
#           [0.24705882, 0.36470588, 0.70196078]],
#
#          [[0.29803922, 0.43137255, 0.76862745],
#           [0.29411765, 0.43137255, 0.76078431],
#           [0.2745098 , 0.41176471, 0.76862745],
#           ...,
#           [0.23529412, 0.34901961, 0.66666667],
#           [0.23137255, 0.36470588, 0.70196078],
#           [0.23137255, 0.36470588, 0.70196078]],
#
#          ...,
#
#          [[0.21960784, 0.32156863, 0.65490196],
#           [0.20784314, 0.30588235, 0.64705882],
#           [0.19215686, 0.29411765, 0.62745098],
#           ...,
#           [0.14509804, 0.25882353, 0.55294118],
#           [0.14901961, 0.2627451 , 0.58039216],
#           [0.17254902, 0.28627451, 0.60392157]],
#
#          [[0.23529412, 0.3372549 , 0.67058824],
#           [0.19607843, 0.30588235, 0.66666667],
#           [0.19607843, 0.29803922, 0.65098039],
#           ...,
#           [0.15294118, 0.25490196, 0.56078431],
#           [0.15294118, 0.25882353, 0.58039216],
#           [0.17254902, 0.28235294, 0.58823529]],
#
#          [[0.23921569, 0.34117647, 0.6745098 ],
#           [0.2       , 0.30980392, 0.67058824],
#           [0.19607843, 0.29803922, 0.65098039],
#           ...,
#           [0.16078431, 0.2627451 , 0.56862745],
#           [0.15294118, 0.25882353, 0.58039216],
#           [0.17647059, 0.28627451, 0.59215686]]],
#
#
#         [[[0.3254902 , 0.44705882, 0.77647059],
#           [0.30196078, 0.41568627, 0.76078431],
#           [0.30196078, 0.41568627, 0.79215686],
#           ...,
#           [0.23921569, 0.36470588, 0.67843137],
#           [0.23921569, 0.35686275, 0.69411765],
#           [0.23921569, 0.34117647, 0.69411765]],
#
#          [[0.3254902 , 0.44705882, 0.77647059],
#           [0.30980392, 0.42745098, 0.76470588],
#           [0.29019608, 0.40784314, 0.77254902],
#           ...,
#           [0.24313725, 0.36862745, 0.68235294],
#           [0.23529412, 0.36078431, 0.69803922],
#           [0.24705882, 0.36078431, 0.70980392]],
#
#          [[0.30588235, 0.42745098, 0.77647059],
#           [0.30196078, 0.42745098, 0.76470588],
#           [0.28235294, 0.40784314, 0.77254902],
#           ...,
#           [0.23921569, 0.35294118, 0.6745098 ],
#           [0.23137255, 0.36078431, 0.70980392],
#           [0.22745098, 0.36078431, 0.69803922]],
#
#          ...,
#
#          [[0.21176471, 0.32156863, 0.65490196],
#           [0.2       , 0.30588235, 0.64705882],
#           [0.18431373, 0.29411765, 0.62745098],
#           ...,
#           [0.15294118, 0.2627451 , 0.54901961],
#           [0.15294118, 0.2627451 , 0.56862745],
#           [0.18039216, 0.28627451, 0.60392157]],
#
#          [[0.22745098, 0.3372549 , 0.67058824],
#           [0.18823529, 0.30588235, 0.66666667],
#           [0.18431373, 0.29803922, 0.64705882],
#           ...,
#           [0.15294118, 0.25882353, 0.55294118],
#           [0.16078431, 0.25882353, 0.57647059],
#           [0.18039216, 0.28627451, 0.58039216]],
#
#          [[0.23529412, 0.34509804, 0.67843137],
#           [0.19215686, 0.30980392, 0.67058824],
#           [0.18823529, 0.30196078, 0.65098039],
#           ...,
#           [0.16078431, 0.26666667, 0.56078431],
#           [0.16078431, 0.25882353, 0.57647059],
#           [0.18431373, 0.29019608, 0.58431373]]],
#
#
#         ...,
#
#
#         [[[0.30980392, 0.44313725, 0.76078431],
#           [0.27843137, 0.41176471, 0.74901961],
#           [0.28235294, 0.40784314, 0.77254902],
#           ...,
#           [0.23921569, 0.35686275, 0.6627451 ],
#           [0.22745098, 0.34901961, 0.67843137],
#           [0.23529412, 0.3372549 , 0.69019608]],
#
#          [[0.30588235, 0.43921569, 0.75686275],
#           [0.28627451, 0.42352941, 0.75294118],
#           [0.27843137, 0.40392157, 0.76470588],
#           ...,
#           [0.24705882, 0.36470588, 0.67058824],
#           [0.23137255, 0.35294118, 0.68235294],
#           [0.24705882, 0.34901961, 0.70196078]],
#
#          [[0.30196078, 0.43137255, 0.76078431],
#           [0.29411765, 0.42745098, 0.74509804],
#           [0.26666667, 0.39607843, 0.74509804],
#           ...,
#           [0.23921569, 0.34509804, 0.6627451 ],
#           [0.23529412, 0.35294118, 0.71372549],
#           [0.23137255, 0.34509804, 0.69411765]],
#
#          ...,
#
#          [[0.19215686, 0.31372549, 0.64313725],
#           [0.19215686, 0.31372549, 0.64313725],
#           [0.19215686, 0.29019608, 0.61176471],
#           ...,
#           [0.14117647, 0.24705882, 0.54117647],
#           [0.15686275, 0.2627451 , 0.58039216],
#           [0.17254902, 0.28235294, 0.58823529]],
#
#          [[0.22745098, 0.32941176, 0.6627451 ],
#           [0.19607843, 0.30980392, 0.65882353],
#           [0.18431373, 0.28235294, 0.64313725],
#           ...,
#           [0.15294118, 0.25490196, 0.56078431],
#           [0.14509804, 0.25098039, 0.56862745],
#           [0.15294118, 0.2745098 , 0.56862745]],
#
#          [[0.22745098, 0.33333333, 0.66666667],
#           [0.18823529, 0.30588235, 0.67058824],
#           [0.18823529, 0.29411765, 0.65490196],
#           ...,
#           [0.14509804, 0.25098039, 0.54509804],
#           [0.15294118, 0.25882353, 0.57647059],
#           [0.16078431, 0.28235294, 0.57647059]]],
#
#
#         [[[0.30980392, 0.44313725, 0.76078431],
#           [0.27843137, 0.41176471, 0.74901961],
#           [0.28235294, 0.40784314, 0.77254902],
#           ...,
#           [0.23137255, 0.36078431, 0.6627451 ],
#           [0.21960784, 0.34901961, 0.67843137],
#           [0.22745098, 0.34117647, 0.69019608]],
#
#          [[0.30588235, 0.43921569, 0.75686275],
#           [0.28627451, 0.42352941, 0.75294118],
#           [0.27843137, 0.40392157, 0.76470588],
#           ...,
#           [0.23921569, 0.36862745, 0.67058824],
#           [0.22352941, 0.35294118, 0.68235294],
#           [0.23921569, 0.35294118, 0.70196078]],
#
#          [[0.30196078, 0.43137255, 0.76078431],
#           [0.29411765, 0.42745098, 0.74509804],
#           [0.26666667, 0.39607843, 0.74509804],
#           ...,
#           [0.23137255, 0.34509804, 0.6627451 ],
#           [0.22745098, 0.35294118, 0.71372549],
#           [0.22352941, 0.34509804, 0.69411765]],
#
#          ...,
#
#          [[0.19215686, 0.31372549, 0.64313725],
#           [0.19215686, 0.31372549, 0.64313725],
#           [0.17647059, 0.29019608, 0.61176471],
#           ...,
#           [0.1372549 , 0.24313725, 0.5372549 ],
#           [0.15294118, 0.25882353, 0.57647059],
#           [0.16470588, 0.2745098 , 0.58039216]],
#
#          [[0.22745098, 0.32941176, 0.6627451 ],
#           [0.19607843, 0.30980392, 0.65882353],
#           [0.18431373, 0.28235294, 0.64313725],
#           ...,
#           [0.15294118, 0.25490196, 0.56078431],
#           [0.14509804, 0.25098039, 0.56862745],
#           [0.15294118, 0.2745098 , 0.56862745]],
#
#          [[0.22745098, 0.33333333, 0.66666667],
#           [0.18823529, 0.30588235, 0.67058824],
#           [0.18823529, 0.29411765, 0.65490196],
#           ...,
#           [0.14509804, 0.25098039, 0.54509804],
#           [0.14901961, 0.25490196, 0.57254902],
#           [0.15686275, 0.27843137, 0.57254902]]],
#
#
#         [[[0.30980392, 0.44313725, 0.76078431],
#           [0.27843137, 0.41176471, 0.74901961],
#           [0.28235294, 0.40784314, 0.77254902],
#           ...,
#           [0.23137255, 0.36470588, 0.65490196],
#           [0.21960784, 0.35294118, 0.67058824],
#           [0.22745098, 0.34509804, 0.68235294]],
#
#          [[0.30588235, 0.43921569, 0.75686275],
#           [0.28627451, 0.42352941, 0.75294118],
#           [0.27843137, 0.40392157, 0.76470588],
#           ...,
#           [0.23921569, 0.37254902, 0.6627451 ],
#           [0.22352941, 0.35686275, 0.67843137],
#           [0.23921569, 0.35686275, 0.69411765]],
#
#          [[0.30196078, 0.43137255, 0.76078431],
#           [0.29411765, 0.42745098, 0.74509804],
#           [0.27058824, 0.4       , 0.74901961],
#           ...,
#           [0.23137255, 0.34901961, 0.65490196],
#           [0.22745098, 0.35686275, 0.70588235],
#           [0.22352941, 0.34901961, 0.68627451]],
#
#          ...,
#
#          [[0.2       , 0.32156863, 0.65098039],
#           [0.19215686, 0.31372549, 0.64313725],
#           [0.18039216, 0.29411765, 0.61568627],
#           ...,
#           [0.1372549 , 0.24313725, 0.5372549 ],
#           [0.15294118, 0.25882353, 0.57647059],
#           [0.16470588, 0.2745098 , 0.58039216]],
#
#          [[0.23137255, 0.33333333, 0.66666667],
#           [0.19607843, 0.30980392, 0.65882353],
#           [0.18431373, 0.28235294, 0.64313725],
#           ...,
#           [0.15294118, 0.25490196, 0.56078431],
#           [0.14509804, 0.25098039, 0.56862745],
#           [0.15294118, 0.2745098 , 0.56862745]],
#
#          [[0.23137255, 0.3372549 , 0.67058824],
#           [0.19215686, 0.30588235, 0.67058824],
#           [0.18823529, 0.29411765, 0.65490196],
#           ...,
#           [0.14509804, 0.25098039, 0.54509804],
#           [0.14901961, 0.25490196, 0.57254902],
#           [0.15686275, 0.27843137, 0.57254902]]]],
#
#
#
#        ...,
#
#
#
#        [[[[0.23529412, 0.38823529, 0.70196078],
#           [0.22745098, 0.38039216, 0.69411765],
#           [0.24313725, 0.40392157, 0.71764706],
#           ...,
#           [0.2627451 , 0.41960784, 0.77254902],
#           [0.25490196, 0.43137255, 0.75294118],
#           [0.25490196, 0.43137255, 0.75294118]],
#
#          [[0.22745098, 0.38039216, 0.69411765],
#           [0.21568627, 0.36862745, 0.68235294],
#           [0.25098039, 0.41176471, 0.7254902 ],
#           ...,
#           [0.24705882, 0.40392157, 0.75686275],
#           [0.23529412, 0.40784314, 0.7372549 ],
#           [0.25098039, 0.42352941, 0.75294118]],
#
#          [[0.21960784, 0.38431373, 0.68235294],
#           [0.22352941, 0.38823529, 0.68627451],
#           [0.25490196, 0.42352941, 0.74509804],
#           ...,
#           [0.24705882, 0.4       , 0.76862745],
#           [0.22745098, 0.39607843, 0.7372549 ],
#           [0.24705882, 0.41568627, 0.75686275]],
#
#          ...,
#
#          [[0.18823529, 0.3372549 , 0.60784314],
#           [0.19215686, 0.34117647, 0.61176471],
#           [0.19607843, 0.34901961, 0.60392157],
#           ...,
#           [0.18823529, 0.33333333, 0.66666667],
#           [0.16470588, 0.30980392, 0.64313725],
#           [0.16470588, 0.30196078, 0.65882353]],
#
#          [[0.18039216, 0.32941176, 0.6       ],
#           [0.19215686, 0.34117647, 0.61176471],
#           [0.19215686, 0.34117647, 0.60784314],
#           ...,
#           [0.19607843, 0.3372549 , 0.65490196],
#           [0.16470588, 0.30980392, 0.64313725],
#           [0.16862745, 0.31372549, 0.64705882]],
#
#          [[0.16862745, 0.31764706, 0.58823529],
#           [0.17647059, 0.3254902 , 0.59607843],
#           [0.18431373, 0.33333333, 0.6       ],
#           ...,
#           [0.17254902, 0.31372549, 0.63137255],
#           [0.16470588, 0.30980392, 0.64313725],
#           [0.16470588, 0.30980392, 0.64313725]]],
#
#
#         [[[0.23529412, 0.38823529, 0.70196078],
#           [0.22745098, 0.38039216, 0.69411765],
#           [0.24313725, 0.4       , 0.7254902 ],
#           ...,
#           [0.25490196, 0.42352941, 0.76470588],
#           [0.24705882, 0.42745098, 0.75686275],
#           [0.25490196, 0.43529412, 0.76470588]],
#
#          [[0.22745098, 0.38039216, 0.69411765],
#           [0.21568627, 0.36862745, 0.68235294],
#           [0.25098039, 0.40784314, 0.73333333],
#           ...,
#           [0.23921569, 0.40784314, 0.74901961],
#           [0.23137255, 0.40784314, 0.74901961],
#           [0.24313725, 0.41960784, 0.76078431]],
#
#          [[0.21960784, 0.38039216, 0.69411765],
#           [0.22352941, 0.38431373, 0.69803922],
#           [0.25490196, 0.41960784, 0.74901961],
#           ...,
#           [0.23529412, 0.4       , 0.75686275],
#           [0.21960784, 0.39215686, 0.74509804],
#           [0.23137255, 0.40392157, 0.75686275]],
#
#          ...,
#
#          [[0.19607843, 0.3372549 , 0.60392157],
#           [0.2       , 0.34117647, 0.60784314],
#           [0.19607843, 0.34901961, 0.60392157],
#           ...,
#           [0.19607843, 0.32941176, 0.66666667],
#           [0.16470588, 0.30980392, 0.64313725],
#           [0.16470588, 0.30196078, 0.65882353]],
#
#          [[0.18823529, 0.32941176, 0.59607843],
#           [0.2       , 0.34117647, 0.60784314],
#           [0.19215686, 0.34117647, 0.60784314],
#           ...,
#           [0.19607843, 0.3372549 , 0.65490196],
#           [0.17254902, 0.30588235, 0.64313725],
#           [0.17647059, 0.30980392, 0.64705882]],
#
#          [[0.18431373, 0.3254902 , 0.59215686],
#           [0.18039216, 0.32156863, 0.58823529],
#           [0.18431373, 0.33333333, 0.6       ],
#           ...,
#           [0.17647059, 0.31764706, 0.63529412],
#           [0.17254902, 0.30588235, 0.64313725],
#           [0.17254902, 0.30588235, 0.64313725]]],
#
#
#         [[[0.23529412, 0.38823529, 0.70196078],
#           [0.23137255, 0.38431373, 0.69803922],
#           [0.24705882, 0.40392157, 0.72941176],
#           ...,
#           [0.2627451 , 0.41960784, 0.77254902],
#           [0.25490196, 0.42745098, 0.75686275],
#           [0.2627451 , 0.43529412, 0.76470588]],
#
#          [[0.22745098, 0.38039216, 0.69411765],
#           [0.21568627, 0.36862745, 0.68235294],
#           [0.25098039, 0.40784314, 0.73333333],
#           ...,
#           [0.24705882, 0.40392157, 0.75686275],
#           [0.23921569, 0.40784314, 0.74901961],
#           [0.25098039, 0.41960784, 0.76078431]],
#
#          [[0.23529412, 0.39607843, 0.70980392],
#           [0.22352941, 0.38431373, 0.69803922],
#           [0.25882353, 0.42352941, 0.75294118],
#           ...,
#           [0.24313725, 0.39607843, 0.76470588],
#           [0.22745098, 0.39215686, 0.74509804],
#           [0.24705882, 0.41176471, 0.76470588]],
#
#          ...,
#
#          [[0.2       , 0.34117647, 0.61176471],
#           [0.2       , 0.34117647, 0.61176471],
#           [0.20392157, 0.35294118, 0.61960784],
#           ...,
#           [0.18823529, 0.31764706, 0.66666667],
#           [0.16862745, 0.30980392, 0.65490196],
#           [0.16470588, 0.30196078, 0.6627451 ]],
#
#          [[0.19215686, 0.33333333, 0.60392157],
#           [0.2       , 0.34117647, 0.61176471],
#           [0.19215686, 0.34117647, 0.61568627],
#           ...,
#           [0.2       , 0.34117647, 0.65882353],
#           [0.17254902, 0.30588235, 0.64313725],
#           [0.18039216, 0.31372549, 0.65098039]],
#
#          [[0.18431373, 0.3254902 , 0.59607843],
#           [0.18431373, 0.3254902 , 0.59607843],
#           [0.18431373, 0.33333333, 0.60392157],
#           ...,
#           [0.17254902, 0.31372549, 0.63137255],
#           [0.17254902, 0.30588235, 0.64313725],
#           [0.17254902, 0.30588235, 0.64313725]]],
#
#
#         ...,
#
#
#         [[[0.23137255, 0.38431373, 0.69803922],
#           [0.22745098, 0.38039216, 0.69411765],
#           [0.24705882, 0.4       , 0.71372549],
#           ...,
#           [0.25490196, 0.41176471, 0.76078431],
#           [0.24313725, 0.41568627, 0.74509804],
#           [0.23921569, 0.41960784, 0.74901961]],
#
#          [[0.22352941, 0.37647059, 0.69019608],
#           [0.21568627, 0.36862745, 0.68235294],
#           [0.25490196, 0.40784314, 0.72156863],
#           ...,
#           [0.23529412, 0.39215686, 0.74901961],
#           [0.23529412, 0.4       , 0.74509804],
#           [0.23921569, 0.41568627, 0.75686275]],
#
#          [[0.23137255, 0.38431373, 0.69411765],
#           [0.22352941, 0.37647059, 0.68627451],
#           [0.25490196, 0.41176471, 0.7372549 ],
#           ...,
#           [0.23137255, 0.39215686, 0.76078431],
#           [0.21568627, 0.38823529, 0.74117647],
#           [0.23921569, 0.41568627, 0.75686275]],
#
#          ...,
#
#          [[0.18823529, 0.32941176, 0.59607843],
#           [0.19607843, 0.3372549 , 0.60392157],
#           [0.19215686, 0.34901961, 0.59215686],
#           ...,
#           [0.17254902, 0.32156863, 0.64705882],
#           [0.16470588, 0.30980392, 0.64313725],
#           [0.16078431, 0.30196078, 0.64705882]],
#
#          [[0.19215686, 0.33333333, 0.6       ],
#           [0.19215686, 0.33333333, 0.6       ],
#           [0.18431373, 0.33333333, 0.59607843],
#           ...,
#           [0.19607843, 0.3372549 , 0.65098039],
#           [0.15294118, 0.30588235, 0.62352941],
#           [0.17647059, 0.30980392, 0.64705882]],
#
#          [[0.18431373, 0.3254902 , 0.59215686],
#           [0.18431373, 0.3254902 , 0.59215686],
#           [0.18039216, 0.32941176, 0.59607843],
#           ...,
#           [0.17254902, 0.31372549, 0.62745098],
#           [0.16078431, 0.31372549, 0.62745098],
#           [0.16470588, 0.29803922, 0.63529412]]],
#
#
#         [[[0.24313725, 0.39607843, 0.70980392],
#           [0.23529412, 0.38823529, 0.70196078],
#           [0.25490196, 0.40784314, 0.72156863],
#           ...,
#           [0.25882353, 0.41960784, 0.76470588],
#           [0.25882353, 0.42352941, 0.75294118],
#           [0.25098039, 0.42352941, 0.75294118]],
#
#          [[0.23137255, 0.38431373, 0.69803922],
#           [0.22352941, 0.37647059, 0.69019608],
#           [0.2627451 , 0.41568627, 0.72941176],
#           ...,
#           [0.23921569, 0.39607843, 0.75294118],
#           [0.24705882, 0.40784314, 0.74901961],
#           [0.25098039, 0.41960784, 0.76078431]],
#
#          [[0.24313725, 0.39607843, 0.70588235],
#           [0.22745098, 0.38039216, 0.69019608],
#           [0.26666667, 0.42352941, 0.74901961],
#           ...,
#           [0.23529412, 0.39607843, 0.76470588],
#           [0.22745098, 0.39215686, 0.74509804],
#           [0.25098039, 0.41960784, 0.76078431]],
#
#          ...,
#
#          [[0.18823529, 0.3372549 , 0.60784314],
#           [0.19607843, 0.34509804, 0.61568627],
#           [0.2       , 0.36078431, 0.61568627],
#           ...,
#           [0.18823529, 0.32156863, 0.65882353],
#           [0.18039216, 0.31372549, 0.65098039],
#           [0.17254902, 0.30196078, 0.65098039]],
#
#          [[0.18823529, 0.3372549 , 0.60784314],
#           [0.19607843, 0.34509804, 0.61568627],
#           [0.18431373, 0.34117647, 0.61176471],
#           ...,
#           [0.2       , 0.34117647, 0.65882353],
#           [0.16078431, 0.31372549, 0.62745098],
#           [0.18039216, 0.31372549, 0.65098039]],
#
#          [[0.18039216, 0.32941176, 0.6       ],
#           [0.18431373, 0.33333333, 0.60392157],
#           [0.18039216, 0.3372549 , 0.60784314],
#           ...,
#           [0.17647059, 0.31764706, 0.63529412],
#           [0.16470588, 0.31764706, 0.63137255],
#           [0.16862745, 0.30196078, 0.63921569]]],
#
#
#         [[[0.24705882, 0.4       , 0.71372549],
#           [0.23921569, 0.39215686, 0.70588235],
#           [0.25098039, 0.41176471, 0.7254902 ],
#           ...,
#           [0.25882353, 0.42745098, 0.77254902],
#           [0.25882353, 0.43137255, 0.76078431],
#           [0.25098039, 0.43137255, 0.76078431]],
#
#          [[0.23529412, 0.38823529, 0.70196078],
#           [0.22745098, 0.38039216, 0.69411765],
#           [0.2627451 , 0.42352941, 0.7372549 ],
#           ...,
#           [0.23921569, 0.40392157, 0.76078431],
#           [0.25098039, 0.41568627, 0.76078431],
#           [0.25098039, 0.42745098, 0.76862745]],
#
#          [[0.24705882, 0.4       , 0.70980392],
#           [0.22745098, 0.38823529, 0.69803922],
#           [0.2627451 , 0.43137255, 0.75294118],
#           ...,
#           [0.23921569, 0.40784314, 0.77647059],
#           [0.22745098, 0.4       , 0.75294118],
#           [0.25098039, 0.42745098, 0.76862745]],
#
#          ...,
#
#          [[0.19215686, 0.34117647, 0.61176471],
#           [0.20392157, 0.35294118, 0.62352941],
#           [0.20392157, 0.36862745, 0.61176471],
#           ...,
#           [0.18823529, 0.32941176, 0.6745098 ],
#           [0.17647059, 0.31764706, 0.6627451 ],
#           [0.17254902, 0.30980392, 0.66666667]],
#
#          [[0.19215686, 0.34117647, 0.61176471],
#           [0.19607843, 0.34509804, 0.61568627],
#           [0.18431373, 0.34117647, 0.61176471],
#           ...,
#           [0.20784314, 0.34509804, 0.6745098 ],
#           [0.17254902, 0.32156863, 0.64705882],
#           [0.18823529, 0.31764706, 0.66666667]],
#
#          [[0.18431373, 0.33333333, 0.60392157],
#           [0.18431373, 0.33333333, 0.60392157],
#           [0.18039216, 0.3372549 , 0.60784314],
#           ...,
#           [0.18039216, 0.31764706, 0.64705882],
#           [0.17254902, 0.32156863, 0.64705882],
#           [0.18039216, 0.30980392, 0.65882353]]]],
#
#
#
#        [[[[0.03529412, 0.03529412, 0.03529412],
#           [0.02745098, 0.03921569, 0.03137255],
#           [0.02745098, 0.03921569, 0.03137255],
#           ...,
#           [0.05098039, 0.03921569, 0.03529412],
#           [0.04705882, 0.03529412, 0.03137255],
#           [0.03921569, 0.03921569, 0.03137255]],
#
#          [[0.03529412, 0.03529412, 0.02745098],
#           [0.03921569, 0.03921569, 0.03921569],
#           [0.03921569, 0.03921569, 0.03137255],
#           ...,
#           [0.05098039, 0.03921569, 0.03529412],
#           [0.05490196, 0.03529412, 0.03137255],
#           [0.03921569, 0.03921569, 0.03137255]],
#
#          [[0.03529412, 0.03529412, 0.03529412],
#           [0.03529412, 0.03529412, 0.02745098],
#           [0.04313725, 0.04313725, 0.03529412],
#           ...,
#           [0.05098039, 0.03921569, 0.03529412],
#           [0.03921569, 0.03921569, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255]],
#
#          ...,
#
#          [[0.05882353, 0.04705882, 0.04313725],
#           [0.05098039, 0.05098039, 0.04313725],
#           [0.0627451 , 0.0627451 , 0.03921569],
#           ...,
#           [0.0745098 , 0.06666667, 0.05098039],
#           [0.06666667, 0.07058824, 0.05098039],
#           [0.07058824, 0.05882353, 0.05490196]],
#
#          [[0.05490196, 0.04313725, 0.04705882],
#           [0.05882353, 0.04705882, 0.04313725],
#           [0.05098039, 0.05098039, 0.04313725],
#           ...,
#           [0.07843137, 0.07058824, 0.05490196],
#           [0.07058824, 0.05882353, 0.0627451 ],
#           [0.08627451, 0.05490196, 0.05490196]],
#
#          [[0.05882353, 0.03921569, 0.03529412],
#           [0.05490196, 0.04313725, 0.03921569],
#           [0.05098039, 0.05098039, 0.05098039],
#           ...,
#           [0.0745098 , 0.0627451 , 0.06666667],
#           [0.07058824, 0.0627451 , 0.04705882],
#           [0.07058824, 0.05882353, 0.05490196]]],
#
#
#         [[[0.03529412, 0.03529412, 0.02745098],
#           [0.02745098, 0.03921569, 0.03137255],
#           [0.02745098, 0.03921569, 0.03137255],
#           ...,
#           [0.05098039, 0.03921569, 0.03529412],
#           [0.03921569, 0.03921569, 0.03137255],
#           [0.03921569, 0.03921569, 0.03137255]],
#
#          [[0.03529412, 0.03529412, 0.02745098],
#           [0.03921569, 0.03921569, 0.03921569],
#           [0.03921569, 0.03921569, 0.03137255],
#           ...,
#           [0.04313725, 0.04313725, 0.03529412],
#           [0.03921569, 0.03921569, 0.03137255],
#           [0.04313725, 0.03137255, 0.02745098]],
#
#          [[0.04705882, 0.03529412, 0.03921569],
#           [0.02745098, 0.03921569, 0.03137255],
#           [0.04313725, 0.04313725, 0.03529412],
#           ...,
#           [0.04313725, 0.04313725, 0.03529412],
#           [0.04705882, 0.03529412, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255]],
#
#          ...,
#
#          [[0.05882353, 0.04705882, 0.04313725],
#           [0.05882353, 0.05098039, 0.03529412],
#           [0.05882353, 0.04705882, 0.04313725],
#           ...,
#           [0.0745098 , 0.0627451 , 0.05882353],
#           [0.07843137, 0.05882353, 0.05490196],
#           [0.07843137, 0.05882353, 0.05490196]],
#
#          [[0.05490196, 0.04313725, 0.03921569],
#           [0.05098039, 0.05098039, 0.04313725],
#           [0.05882353, 0.04705882, 0.04313725],
#           ...,
#           [0.0745098 , 0.0627451 , 0.05882353],
#           [0.08235294, 0.0627451 , 0.05882353],
#           [0.07843137, 0.05882353, 0.05490196]],
#
#          [[0.05882353, 0.03921569, 0.03529412],
#           [0.05490196, 0.04313725, 0.04705882],
#           [0.05882353, 0.04705882, 0.05098039],
#           ...,
# ...
#           [0.03921569, 0.03921569, 0.03921569],
#           [0.03921569, 0.03921569, 0.03137255],
#           ...,
#           [0.05098039, 0.03921569, 0.03529412],
#           [0.03921569, 0.03921569, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255]],
#
#          ...,
#
#          [[0.04705882, 0.04705882, 0.03921569],
#           [0.05098039, 0.05098039, 0.04313725],
#           [0.05882353, 0.04705882, 0.04313725],
#           ...,
#           [0.07843137, 0.07058824, 0.05490196],
#           [0.07058824, 0.05882353, 0.05490196],
#           [0.07843137, 0.0627451 , 0.04705882]],
#
#          [[0.05490196, 0.04313725, 0.03921569],
#           [0.04705882, 0.04705882, 0.03921569],
#           [0.05882353, 0.04705882, 0.04313725],
#           ...,
#           [0.0745098 , 0.0627451 , 0.05882353],
#           [0.07843137, 0.05882353, 0.05490196],
#           [0.07058824, 0.05882353, 0.05490196]],
#
#          [[0.05490196, 0.04313725, 0.03921569],
#           [0.04705882, 0.04705882, 0.03921569],
#           [0.05098039, 0.05098039, 0.04313725],
#           ...,
#           [0.0745098 , 0.0627451 , 0.05882353],
#           [0.07843137, 0.05882353, 0.05490196],
#           [0.07058824, 0.05882353, 0.05490196]]],
#
#
#         [[[0.03529412, 0.03529412, 0.03529412],
#           [0.02745098, 0.03921569, 0.03137255],
#           [0.03921569, 0.03921569, 0.03137255],
#           ...,
#           [0.03921569, 0.03921569, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255]],
#
#          [[0.03529412, 0.03529412, 0.02745098],
#           [0.03529412, 0.03529412, 0.02745098],
#           [0.03921569, 0.03921569, 0.03137255],
#           ...,
#           [0.03921569, 0.03921569, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255]],
#
#          [[0.03529412, 0.03529412, 0.02745098],
#           [0.03921569, 0.03921569, 0.03921569],
#           [0.03921569, 0.03921569, 0.03137255],
#           ...,
#           [0.04313725, 0.04313725, 0.03529412],
#           [0.03921569, 0.03921569, 0.03137255],
#           [0.04705882, 0.03529412, 0.03921569]],
#
#          ...,
#
#          [[0.04705882, 0.04705882, 0.03921569],
#           [0.05882353, 0.04705882, 0.04313725],
#           [0.05098039, 0.05098039, 0.04313725],
#           ...,
#           [0.07843137, 0.07058824, 0.05490196],
#           [0.07058824, 0.05882353, 0.05490196],
#           [0.07058824, 0.05882353, 0.05490196]],
#
#          [[0.04705882, 0.04705882, 0.03921569],
#           [0.04705882, 0.04705882, 0.03921569],
#           [0.05882353, 0.04705882, 0.04313725],
#           ...,
#           [0.0745098 , 0.0627451 , 0.05882353],
#           [0.07843137, 0.05882353, 0.05490196],
#           [0.07058824, 0.05882353, 0.05490196]],
#
#          [[0.04313725, 0.04313725, 0.03529412],
#           [0.04705882, 0.04705882, 0.03921569],
#           [0.05098039, 0.05098039, 0.04313725],
#           ...,
#           [0.0745098 , 0.0627451 , 0.05882353],
#           [0.07843137, 0.05882353, 0.05490196],
#           [0.07058824, 0.05882353, 0.05490196]]],
#
#
#         [[[0.03529412, 0.03529412, 0.03529412],
#           [0.03921569, 0.03921569, 0.03137255],
#           [0.03137255, 0.04313725, 0.03529412],
#           ...,
#           [0.05098039, 0.03921569, 0.04313725],
#           [0.04705882, 0.03529412, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255]],
#
#          [[0.03529412, 0.03529412, 0.02745098],
#           [0.03921569, 0.03921569, 0.03137255],
#           [0.03921569, 0.03921569, 0.03137255],
#           ...,
#           [0.04705882, 0.03529412, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255]],
#
#          [[0.03529412, 0.03529412, 0.02745098],
#           [0.03921569, 0.03921569, 0.03921569],
#           [0.03921569, 0.03921569, 0.03137255],
#           ...,
#           [0.04313725, 0.04313725, 0.03529412],
#           [0.03921569, 0.03921569, 0.03137255],
#           [0.04705882, 0.03529412, 0.03137255]],
#
#          ...,
#
#          [[0.04705882, 0.04705882, 0.03921569],
#           [0.05882353, 0.04705882, 0.04313725],
#           [0.05882353, 0.04705882, 0.04313725],
#           ...,
#           [0.0745098 , 0.0627451 , 0.05882353],
#           [0.07058824, 0.05882353, 0.05490196],
#           [0.07058824, 0.05882353, 0.05490196]],
#
#          [[0.05490196, 0.04313725, 0.03921569],
#           [0.05490196, 0.04313725, 0.03921569],
#           [0.05882353, 0.04705882, 0.04313725],
#           ...,
#           [0.0745098 , 0.0627451 , 0.05882353],
#           [0.07843137, 0.05882353, 0.05490196],
#           [0.07058824, 0.05882353, 0.05490196]],
#
#          [[0.04313725, 0.04313725, 0.03529412],
#           [0.04705882, 0.04705882, 0.03921569],
#           [0.05098039, 0.05098039, 0.04313725],
#           ...,
#           [0.0745098 , 0.0627451 , 0.05882353],
#           [0.07058824, 0.05882353, 0.05490196],
#           [0.07058824, 0.0627451 , 0.04705882]]]],
#
#
#
#        [[[[0.34117647, 0.34117647, 0.33333333],
#           [0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.35294118, 0.35294118, 0.34509804],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.90980392, 0.90980392, 0.90196078],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          ...,
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.25882353, 0.25882353, 0.25098039],
#           [0.25882353, 0.25882353, 0.25098039],
#           [0.26666667, 0.25490196, 0.25098039]],
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.25882353, 0.25882353, 0.25098039],
#           [0.2627451 , 0.25098039, 0.25490196]],
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.2745098 , 0.2745098 , 0.26666667],
#           ...,
#           [0.25882353, 0.25882353, 0.25882353],
#           [0.25882353, 0.25882353, 0.25882353],
#           [0.2627451 , 0.25098039, 0.25490196]]],
#
#
#         [[[0.34117647, 0.34117647, 0.33333333],
#           [0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.35294118, 0.35294118, 0.34509804],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.90980392, 0.90980392, 0.90196078],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          ...,
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.25490196, 0.25490196, 0.24705882],
#           [0.25490196, 0.25490196, 0.24705882]],
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.25490196, 0.25490196, 0.25490196]],
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.2745098 , 0.2745098 , 0.26666667],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.25098039, 0.25490196]]],
#
#
#         [[[0.34117647, 0.34117647, 0.33333333],
#           [0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.35294118, 0.35294118, 0.34509804],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.90980392, 0.90980392, 0.90196078],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          ...,
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.25098039, 0.24705882]],
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.25098039, 0.25490196]],
#
#          [[0.26666667, 0.26666667, 0.25882353],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.2745098 , 0.2745098 , 0.26666667],
#           ...,
#           [0.25882353, 0.25882353, 0.25098039],
#           [0.25882353, 0.25882353, 0.25098039],
#           [0.2627451 , 0.25098039, 0.25490196]]],
#
#
#         ...,
#
#
#         [[[0.34117647, 0.34117647, 0.33333333],
#           [0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.35294118, 0.35294118, 0.34509804],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.90980392, 0.90980392, 0.90196078],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          ...,
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.25490196, 0.25490196, 0.25490196]],
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.25882353, 0.25882353, 0.25882353]],
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.25490196, 0.25490196, 0.24705882],
#           [0.25490196, 0.25490196, 0.25490196]]],
#
#
#         [[[0.34117647, 0.34117647, 0.33333333],
#           [0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.35294118, 0.35294118, 0.34509804],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.90980392, 0.90980392, 0.90196078],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          ...,
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.25882353, 0.25882353, 0.25098039]],
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.25882353, 0.25882353, 0.25098039]],
#
#          [[0.26666667, 0.26666667, 0.25882353],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.25882353, 0.25882353, 0.25882353],
#           [0.25490196, 0.25490196, 0.25490196]]],
#
#
#         [[[0.34117647, 0.34117647, 0.33333333],
#           [0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.35294118, 0.35294118, 0.34509804],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          [[0.34509804, 0.34509804, 0.3372549 ],
#           [0.34901961, 0.34901961, 0.34117647],
#           [0.90980392, 0.90980392, 0.90196078],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196]],
#
#          ...,
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.25882353, 0.25882353, 0.25882353]],
#
#          [[0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.27843137, 0.27843137, 0.27058824],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.26666667, 0.24705882]],
#
#          [[0.26666667, 0.26666667, 0.25882353],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           [0.27058824, 0.27058824, 0.2627451 ],
#           ...,
#           [0.2627451 , 0.2627451 , 0.25490196],
#           [0.2627451 , 0.2627451 , 0.2627451 ],
#           [0.25882353, 0.25882353, 0.25882353]]]]])

# %% [markdown]
# ## **<font style="color:#112B3C">Split the Data into Train and Test Set</font>**
#
# As of now, we have the required **`features`** (a NumPy array containing all the extracted frames of the videos) and **`one_hot_encoded_labels`** (also a Numpy array containing all class labels in one hot encoded format). So now, we will split our data to create training and testing sets. We will also shuffle the dataset before the split to avoid any bias and get splits representing the overall distribution of the data.

# %%
# Split the Data into Train ( 75% ) and Test Set ( 25% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, labels,
                                                                            test_size = 0.25, shuffle = True,
                                                                            random_state = seed_constant)

# %%
len(set(labels)), len(set(labels_train)), len(set(labels_test))
# Out:
# (797, 635, 236)

# %%
NB_CLASSES = len(set(labels_train))
NB_CLASSES
# Out:
# 635

# %% [markdown]
# Now we will convert `labels` (class indexes) into one-hot encoded vectors.

# %%
labels_train = tf.one_hot(labels_train, NB_CLASSES)

# %%
labels_test = tf.one_hot(labels_test, NB_CLASSES)

# %% [markdown]
# ## **<font style="color:#112B3C">ConvLSTM Approach</font>**
#
# In this step, we will implement the first approach by using a combination of ConvLSTM cells. A ConvLSTM cell is a variant of an LSTM network that contains convolutions operations in the network. it is an LSTM with convolution embedded in the architecture, which makes it capable of identifying spatial features of the data while keeping into account the temporal relation.
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1KHN_JFWJoJi1xQj_bRdxy2QgevGOH1qP" width= 500px>
# </center>
#
#
# For video classification, this approach effectively captures the spatial relation in the individual frames and the temporal relation across the different frames. As a result of this convolution structure, the ConvLSTM is capable of taking in 3-dimensional input `(width, height, num_of_channels)` whereas a simple LSTM only takes in 1-dimensional input hence an LSTM is incompatible for modeling Spatio-temporal data on its own.
#
# You can read the paper [**Convolutional LSTM Network: A Machine Learning Approach for Precipitation Nowcasting**](https://arxiv.org/abs/1506.04214v1) by **Xingjian Shi** (NIPS 2015), to learn more about this architecture.

# %% [markdown]
# ### **<font style="color:#205375">Construct the Model</font>**
#
#
# To construct the model, we will use Keras [**`ConvLSTM2D`**](https://keras.io/api/layers/recurrent_layers/conv_lstm2d) recurrent layers. The **`ConvLSTM2D`** layer also takes in the number of filters and kernel size required for applying the convolutional operations. The output of the layers is flattened in the end and is fed to the **`Dense`** layer with softmax activation which outputs the probability of each action category.
#
# We will also use **`MaxPooling3D`** layers to reduce the dimensions of the frames and avoid unnecessary computations and **`Dropout`** layers to prevent [overfitting](https://en.wikipedia.org/wiki/Overfitting) the model on the data. The architecture is a simple one and has a small number of trainable parameters. This is because we are only dealing with a small subset of the dataset which does not require a large-scale model.

# %%
def create_convlstm_model():
    '''
    This function will construct the required convlstm model.
    Returns:
        model: It is the required constructed convlstm model.
    '''

    # We will use a Sequential model for model construction
    model = Sequential()

    # Define the Model Architecture.
    ########################################################################################################################

    model.add(ConvLSTM2D(filters = 4, kernel_size = (3, 3), activation = 'tanh',data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True, input_shape = (SEQUENCE_LENGTH,
                                                                                      IMAGE_HEIGHT, IMAGE_WIDTH, 3)))

    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))

    model.add(ConvLSTM2D(filters = 8, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))

    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))

    model.add(ConvLSTM2D(filters = 14, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))

    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))

    model.add(ConvLSTM2D(filters = 16, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))

    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    #model.add(TimeDistributed(Dropout(0.2)))

    model.add(Flatten())

    model.add(Dense(NB_CLASSES, activation = "softmax"))

    ########################################################################################################################

    # Display the models summary.
    model.summary()

    # Return the constructed convlstm model.
    return model

# %% [markdown]
# Now we will utilize the function **`create_convlstm_model()`** created above, to construct the required `convlstm` model.

# %%
# Construct the required convlstm model.
convlstm_model = create_convlstm_model()

# Display the success message.
print("Model Created Successfully!")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)             │ (None, 20, 62, 62, 4)       │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d (MaxPooling3D)         │ (None, 20, 31, 31, 4)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed (TimeDistributed)   │ (None, 20, 31, 31, 4)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)           │ (None, 20, 29, 29, 8)       │           3,488 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_1 (MaxPooling3D)       │ (None, 20, 15, 15, 8)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_1 (TimeDistributed) │ (None, 20, 15, 15, 8)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_2 (ConvLSTM2D)           │ (None, 20, 13, 13, 14)      │          11,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_2 (MaxPooling3D)       │ (None, 20, 7, 7, 14)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_2 (TimeDistributed) │ (None, 20, 7, 7, 14)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_3 (ConvLSTM2D)           │ (None, 20, 5, 5, 16)        │          17,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_3 (MaxPooling3D)       │ (None, 20, 3, 3, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2880)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 635)                 │       1,829,435 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,862,435 (7.10 MB)
#  Trainable params: 1,862,435 (7.10 MB)
#  Non-trainable params: 0 (0.00 B)
# Model Created Successfully!

# %% [markdown]
# #### **<font style="color:#205375">Check Model’s Structure:</font>**
#
# Now we will use the **`plot_model()`** function, to check the structure of the constructed model, this is helpful while constructing a complex network and making that the network is created correctly.

# %%
# Plot the structure of the contructed model.
plot_model(convlstm_model, to_file = 'convlstm_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %%
# Create an Instance of Early Stopping Callback
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'min', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics values to the model
convlstm_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 4,
                                                     shuffle = True, validation_split = 0.2,

                                                     callbacks = [early_stopping_callback])
# Out:
# Epoch 1/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 77s 93ms/step - accuracy: 0.0000e+00 - loss: 4.3113 - val_accuracy: 0.0000e+00 - val_loss: 5.6222
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 26s 51ms/step - accuracy: 0.0000e+00 - loss: 3.6205 - val_accuracy: 0.0000e+00 - val_loss: 5.9896
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 8.5311e-04 - loss: 3.0296 - val_accuracy: 0.0000e+00 - val_loss: 5.9633
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.0000e+00 - loss: 2.9717 - val_accuracy: 0.0000e+00 - val_loss: 5.9749
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.0000e+00 - loss: 2.9669 - val_accuracy: 0.0000e+00 - val_loss: 6.0114
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - accuracy: 0.0000e+00 - loss: 2.9611 - val_accuracy: 0.0000e+00 - val_loss: 6.0683
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.0000e+00 - loss: 2.9492 - val_accuracy: 0.0000e+00 - val_loss: 6.0450
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.0000e+00 - loss: 2.9438 - val_accuracy: 0.0000e+00 - val_loss: 6.1010
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.0000e+00 - loss: 2.9405 - val_accuracy: 0.0000e+00 - val_loss: 6.3362
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.0000e+00 - loss: 2.9423 - val_accuracy: 0.0000e+00 - val_loss: 6.2024
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.0000e+00 - loss: 2.9410 - val_accuracy: 0.0000e+00 - val_loss: 6.2746

# %% [markdown]
# #### **<font style="color:#205375">Evaluate the Trained Model</font>**
#
# After training, we will evaluate the model on the test set.

# %%
# Evaluate the trained model.
model_evaluation_history = convlstm_model.evaluate(features_test, labels_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 360ms/step - accuracy: 0.0000e+00 - loss: 5.1226

# %% [markdown]
# #### **<font style="color:#205375">Save the Model</font>**
#
# Now we will save the model to avoid training it from scratch every time we need the model.

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'convlstm_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Save your Model.
convlstm_model.save(model_file_name)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### **<font style="color:#205375">Plot Model’s Loss & Accuracy Curves</font>**
#
#
# Now we will create a function **`plot_metric()`** to visualize the training and validation metrics. We already have separate metrics from our training and validation steps so now we just have to visualize them.

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''

    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]

    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# %% [markdown]
# Now we will utilize the function **`plot_metric()`** created above, to visualize and understand the metrics.

# %%
# Visualize the training and validation loss metrices.
plot_metric(convlstm_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(convlstm_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %% [markdown]
# ## **<font style="color:#112B3C">LRCN Approach</font>**
#
# In this step, we will implement the LRCN Approach by combining Convolution and LSTM layers in a single model. Another similar approach can be to use a CNN model and LSTM model trained separately. The CNN model can be used to extract spatial features from the frames in the video, and for this purpose, a pre-trained model can be used, that can be fine-tuned for the problem. And the LSTM model can then use the features extracted by CNN, to predict the action being performed in the video.
#
#
# But here, we will implement another approach known as the Long-term Recurrent Convolutional Network (LRCN), which combines CNN and LSTM layers in a single model. The Convolutional layers are used for spatial feature extraction from the frames, and the extracted spatial features are fed to LSTM layer(s) at each time-steps for temporal sequence modeling. This way the network learns spatiotemporal features directly in an end-to-end training, resulting in a robust model.
#
# <center>
# <img src='https://drive.google.com/uc?export=download&id=1I-q5yLsIoNh2chfzT7JYvra17FsXvdme'>
# </center>
#
#
# You can read the paper [Long-term Recurrent Convolutional Networks for Visual Recognition and Description](https://arxiv.org/abs/1411.4389?source=post_page---------------------------) by Jeff Donahue (CVPR 2015), to learn more about this architecture.
#
# We will also use [**`TimeDistributed`**](https://keras.io/api/layers/recurrent_layers/time_distributed/) wrapper layer, which allows applying the same layer to every frame of the video independently. So it makes a layer (around which it is wrapped) capable of taking input of shape `(no_of_frames, width, height, num_of_channels)` if originally the layer's input shape was `(width, height, num_of_channels)` which is very beneficial as it allows to input the whole video into the model in a single shot.
#
# <center>
# <img src='https://drive.google.com/uc?export=download&id=1CbauSm5XTY7ypHYBHH7rDSnJ5LO9CUWX' width=400>
# </center>

# %% [markdown]
# ### **<font style="color:#205375">Construct the Model</font>**
#
# To implement our LRCN architecture, we will use time-distributed **`Conv2D`** layers which will be followed by **`MaxPooling2D`** and **`Dropout`** layers. The feature extracted from the **`Conv2D`** layers will be then flattened using the  **`Flatten`** layer and will be fed to a **`LSTM`** layer. The **`Dense`** layer with softmax activation will then use the output from the **`LSTM`** layer to predict the action being performed.

# %%
def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()

    # Define the Model Architecture.
    ########################################################################################################################

    model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu'),
                              input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))

    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.25)))

    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.25)))

    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Dropout(0.25)))

    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    #model.add(TimeDistributed(Dropout(0.25)))

    model.add(TimeDistributed(Flatten()))

    model.add(LSTM(32))

    model.add(Dense(NB_CLASSES, activation = 'softmax'))

    ########################################################################################################################

    # Display the models summary.
    model.summary()

    # Return the constructed LRCN model.
    return model

# %% [markdown]
# Now we will utilize the function **`create_LRCN_model()`** created above to construct the required `LRCN` model.

# %%
# Construct the required LRCN model.
LRCN_model = create_LRCN_model()

# Display the success message.
print("Model Created Successfully!")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed_3 (TimeDistributed) │ (None, 20, 64, 64, 16)      │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_4 (TimeDistributed) │ (None, 20, 16, 16, 16)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_5 (TimeDistributed) │ (None, 20, 16, 16, 16)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_6 (TimeDistributed) │ (None, 20, 16, 16, 32)      │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_7 (TimeDistributed) │ (None, 20, 4, 4, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_8 (TimeDistributed) │ (None, 20, 4, 4, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_9 (TimeDistributed) │ (None, 20, 4, 4, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_10                  │ (None, 20, 2, 2, 64)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_11                  │ (None, 20, 2, 2, 64)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_12                  │ (None, 20, 2, 2, 64)        │          36,928 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_13                  │ (None, 20, 1, 1, 64)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_14                  │ (None, 20, 64)              │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 635)                 │          20,955 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 93,883 (366.73 KB)
#  Trainable params: 93,883 (366.73 KB)
#  Non-trainable params: 0 (0.00 B)
# Model Created Successfully!

# %% [markdown]
# #### **<font style="color:#205375">Check Model’s Structure:</font>**
#
# Now we will use the **`plot_model()`** function to check the structure of the constructed `LRCN` model. As we had checked for the previous model.

# %%
# Plot the structure of the contructed LRCN model.
plot_model(LRCN_model, to_file = 'LRCN_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# ### **<font style="color:#205375">Compile & Train the Model</font>**
#
#
# After checking the structure, we will compile and start training the model.

# %%
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics to the model.
LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 70, batch_size = 4 ,
                                             shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 69ms/step - accuracy: 2.0948e-04 - loss: 2.8018 - val_accuracy: 0.0000e+00 - val_loss: 3.1337
# Epoch 2/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.0076 - loss: 2.2872 - val_accuracy: 0.0000e+00 - val_loss: 3.4639
# Epoch 3/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 1.7269e-04 - loss: 2.2850 - val_accuracy: 0.0000e+00 - val_loss: 3.6426
# Epoch 4/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 1.8486e-04 - loss: 2.3051 - val_accuracy: 0.0000e+00 - val_loss: 3.7584
# Epoch 5/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - accuracy: 1.8486e-04 - loss: 2.3156 - val_accuracy: 0.0000e+00 - val_loss: 3.8407
# Epoch 6/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 1.8486e-04 - loss: 2.3193 - val_accuracy: 0.0000e+00 - val_loss: 3.9040
# Epoch 7/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 1.8486e-04 - loss: 2.3199 - val_accuracy: 0.0000e+00 - val_loss: 3.9561
# Epoch 8/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 1.8486e-04 - loss: 2.3196 - val_accuracy: 0.0000e+00 - val_loss: 4.0012
# Epoch 9/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 1.8486e-04 - loss: 2.3190 - val_accuracy: 0.0000e+00 - val_loss: 4.0415
# Epoch 10/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 1.8486e-04 - loss: 2.3183 - val_accuracy: 0.0000e+00 - val_loss: 4.0785
# Epoch 11/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 1.8486e-04 - loss: 2.3178 - val_accuracy: 0.0000e+00 - val_loss: 4.1130
# Epoch 12/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 1.8486e-04 - loss: 2.3173 - val_accuracy: 0.0000e+00 - val_loss: 4.1457
# Epoch 13/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 1.8486e-04 - loss: 2.3168 - val_accuracy: 0.0000e+00 - val_loss: 4.1770
# Epoch 14/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 1.8486e-04 - loss: 2.3165 - val_accuracy: 0.0000e+00 - val_loss: 4.2072
# Epoch 15/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - accuracy: 1.8486e-04 - loss: 2.3161 - val_accuracy: 0.0000e+00 - val_loss: 4.2365
# Epoch 16/70
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - accuracy: 1.8486e-04 - loss: 2.3158 - val_accuracy: 0.0000e+00 - val_loss: 4.2651

# %% [markdown]
# #### **<font style="color:205375">Evaluating the trained Model</font>**
#
# As done for the previous one, we will evaluate the `LRCN` model on the test set.

# %%
# Evaluate the trained model.
model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0000e+00 - loss: 2.9552

# %% [markdown]
# #### **<font style="color:#205375">Save the Model</font>**
#
# After that, we will save the model for future uses using the same technique we had used for the previous model.

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'LRCN_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Save the Model.
LRCN_model.save(model_file_name)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### **<font style="color:#205375">Plot Model’s Loss & Accuracy Curves</font>**
#
# Now we will utilize the function **`plot_metric()`** we had created above to visualize the training and validation metrics of this model.

# %%
# Visualize the training and validation loss metrices.
plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %% [markdown]
# ## **<font style="color:#112B3C">Test the Best Performing Model</font>**
#
# From the results, it seems that the LRCN model performed significantly well for a small number of classes. so in this step, we will put the `LRCN` model to test on some youtube videos.

# %% [markdown]
# ### **<font style="color:#205375">Create a Function to Download YouTube Videos:</font>**
#
# We will create a function **`download_youtube_videos()`** to download the YouTube videos first using **`pafy`** library. The library only requires a URL to a video to download it along with its associated metadata like the title of the video.

# %%
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
# !pip uninstall pytube -y
# !pip install git+https://github.com/pytube/pytube
# Out:
# WARNING: Skipping pytube as it is not installed.
# Collecting git+https://github.com/pytube/pytube
#   Cloning https://github.com/pytube/pytube to /tmp/pip-req-build-pla32mhe
#   Running command git clone --filter=blob:none --quiet https://github.com/pytube/pytube /tmp/pip-req-build-pla32mhe
#   Resolved https://github.com/pytube/pytube to commit a32fff39058a6f7e5e59ecd06a7467b71197ce35
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pytube
#   Building wheel for pytube (setup.py) ... done
#   Created wheel for pytube: filename=pytube-15.0.0-py3-none-any.whl size=57580 sha256=ecd97962f4839095dbe84c813a6587cfb769e881caeea005f7ca68696c7db650
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3rtkdflv/wheels/5e/2a/b2/3c57f9cd8542ae82cd4247378230ac2e764e884224581a7072
# Successfully built pytube
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
import os
from pytube import YouTube

def download_youtube_videos(youtube_video_url, output_directory):
    '''
    This function downloads the YouTube video whose URL is passed to it as an argument.
    Args:
        youtube_video_url: URL of the video that is required to be downloaded.
        output_directory: The directory path to which the video needs to be stored after downloading.
    Returns:
        output_file_path: The path of the downloaded YouTube video.
    '''
    try:
        # Create a YouTube object
        video = YouTube(youtube_video_url)

        # Retrieve the title of the video.
        title = video.title

        # Get the best available quality for the video.
        video_best = video.streams.get_highest_resolution()

        # Ensure the output directory exists
        os.makedirs(output_directory, exist_ok=True)

        # Construct the output file path
        output_file_path = os.path.join(output_directory, f"{title}.mp4")

        # Download the video
        video_best.download(output_path=output_directory)

        print(f"✅ Video downloaded successfully: {output_file_path}")
        return output_file_path
    except Exception as e:
        print(f"❌ Error: {e}")
        return None

# Set the output directory
test_videos_directory = 'test_videos'
os.makedirs(test_videos_directory, exist_ok=True)

# Provide the YouTube video URL
youtube_url = 'https://www.youtube.com/watch?v=Ebk5o9aU2VM'  # Replace with actual URL

# Download the video and get its path
input_video_file_path = download_youtube_videos(youtube_url, test_videos_directory)
# Out:
# ❌ Error: HTTP Error 400: Bad Request

# %% [markdown]
# ### **<font style="color:#205375">Download a Test Video:</font>**
#
# Now we will utilize the function **`download_youtube_videos()`** created above to download a youtube video on which the `LRCN` model will be tested.

# %%
test_videos_directory = 'test_videos'
os.makedirs(test_videos_directory, exist_ok=True)

# Download a YouTube Video.
video_title = download_youtube_videos('https://www.youtube.com/watch?v=Ebk5o9aU2VM', test_videos_directory)

# Get the YouTube Video's path we just downloaded.
input_video_file_path = os.path.join(test_videos_directory, f"{video_title}.mp4")

print(f"✅ Video downloaded successfully: {input_video_file_path}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-60100eb65088> in <cell line: 0>()
#       3
#       4 # Download a YouTube Video.
# ----> 5 video_title = download_youtube_videos('https://www.youtube.com/watch?v=Ebk5o9aU2VM', test_videos_directory)
#       6
#       7 # Get the YouTube Video's path we just downloaded.
#
# <ipython-input-85-a7f7d924091b> in download_youtube_videos(youtube_video_url, output_directory)
#      26     # Download the youtube video at the best available quality and store it to the contructed path.
#      27     # Adding headers to the download request to mimic a browser request
# ---> 28     video_best.download(filepath=output_file_path, quiet=True, headers={'User-Agent': 'Mozilla/5.0'})
#      29
#      30     # Return the video title.
#
# TypeError: YtdlStream.download() got an unexpected keyword argument 'headers'

# %%
# !pip install --upgrade youtube-dl

# %% [markdown]
# ### **<font style="color:#205375">Create a Function To Perform Action Recognition on Videos</font>**
#
# Next, we will create a function **`predict_on_video()`** that will simply read a video frame by frame from the path passed in as an argument and will perform action recognition on video and save the results.

# %%
def predict_on_video(video_file_path, output_file_path, SEQUENCE_LENGTH):
    '''
    This function will perform ASL on a video using the LRCN model.
    Args:
    video_file_path:  The path of the video stored in the disk on which the ASL is to be performed.
    output_file_path: The path where the ouput video with the predicted action being performed overlayed will be stored.
    SEQUENCE_LENGTH:  The fixed number of frames of a video that can be passed to the model as one sequence.
    '''

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv2.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Initialize the VideoWriter Object to store the output video in the disk.
    video_writer = cv2.VideoWriter(output_file_path, cv2.VideoWriter_fourcc('M', 'P', '4', 'V'),
                                   video_reader.get(cv2.CAP_PROP_FPS), (original_video_width, original_video_height))

    # Declare a queue to store video frames.
    frames_queue = deque(maxlen = SEQUENCE_LENGTH)

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    # Iterate until the video is accessed successfully.
    while video_reader.isOpened():

        # Read the frame.
        ok, frame = video_reader.read()

        # Check if frame is not read properly then break the loop.
        if not ok:
            break

        # Resize the Frame to fixed Dimensions.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
        normalized_frame = resized_frame / 255

        # Appending the pre-processed frame into the frames list.
        frames_queue.append(normalized_frame)

        # Check if the number of frames in the queue are equal to the fixed sequence length.
        if len(frames_queue) == SEQUENCE_LENGTH:

            # Pass the normalized frames to the model and get the predicted probabilities.
            predicted_labels_probabilities = LRCN_model.predict(np.expand_dims(frames_queue, axis = 0))[0]

            # Get the index of class with highest probability.
            predicted_label = np.argmax(predicted_labels_probabilities)

            # Get the class name using the retrieved index.
            predicted_class_name = CLASSES_LIST[predicted_label]

        # Write predicted class name on top of the frame.
        cv2.putText(frame, predicted_class_name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # Write The frame into the disk using the VideoWriter Object.
        video_writer.write(frame)

    # Release the VideoCapture and VideoWriter objects.
    video_reader.release()
    video_writer.release()

# %% [markdown]
# ### **<font style="color:#205375">Perform Action Recognition on the Test Video</font>**
#
# Now we will utilize the function **`predict_on_video()`** created above to perform action recognition on the test video we had downloaded using the function **`download_youtube_videos()`** and display the output video with the predicted action overlayed on it.

# %%
#!wget install https://files.pythonhosted.org/packages/18/54/01a8c4e35c75ca9724d19a7e4de9dc23f0ceb8769102c7de056113af61c3/moviepy-1.0.3.tar.gz

# %%
pip install setuptools

# %%
from moviepy.editor import VideoFileClip

# %%
# Construct the output video path.
output_video_file_path = f'{test_videos_directory}{video_title}-Output-SeqLen{SEQUENCE_LENGTH}.mp4'
#output_video_file_path = f'{DATASET_DIR}/69241-Output-SeqLen{SEQUENCE_LENGTH}.mp4'

# Perform Action Recognition on the Test Video.
predict_on_video(input_video_file_path, output_video_file_path, SEQUENCE_LENGTH)
#predict_on_video(f'{DATASET_DIR}/69241.mp4', output_video_file_path, SEQUENCE_LENGTH)

# Display the output video.
VideoFileClip(output_video_file_path, audio=False, target_resolution=(300,None)).ipython_display()

# %% [markdown]
# ### **<font style="color:#205375">Create a Function To Perform a Single Prediction on Videos</font>**
#
#
# Now let's create a function that will perform a single prediction for the complete videos. We will extract evenly distributed **N** **`(SEQUENCE_LENGTH)`** frames from the entire video and pass them to the `LRCN` model. This approach is really useful when you are working with videos containing only one activity as it saves unnecessary computations and time in that scenario.

# %%
def predict_single_action(video_file_path, SEQUENCE_LENGTH):
    '''
    This function will perform single action recognition prediction on a video using the LRCN model.
    Args:
    video_file_path:  The path of the video stored in the disk on which the action recognition is to be performed.
    SEQUENCE_LENGTH:  The fixed number of frames of a video that can be passed to the model as one sequence.
    '''

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv2.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Declare a list to store video frames we will extract.
    frames_list = []

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    # Get the number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH),1)

    # Iterating the number of times equal to the fixed length of sequence.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Read a frame.
        success, frame = video_reader.read()

        # Check if frame is not read properly then break the loop.
        if not success:
            break

        # Resize the Frame to fixed Dimensions.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
        normalized_frame = resized_frame / 255

        # Appending the pre-processed frame into the frames list
        frames_list.append(normalized_frame)

    # Passing the  pre-processed frames to the model and get the predicted probabilities.
    predicted_labels_probabilities = LRCN_model.predict(np.expand_dims(frames_list, axis = 0))[0]

    # Get the index of class with highest probability.
    predicted_label = np.argmax(predicted_labels_probabilities)

    # Get the class name using the retrieved index.
    predicted_class_name = CLASSES_LIST[predicted_label]

    # Display the predicted action along with the prediction confidence.
    print(f'Action Predicted: {predicted_class_name}\nConfidence: {predicted_labels_probabilities[predicted_label]}')

    # Release the VideoCapture object.
    video_reader.release()

# %% [markdown]
# ### **<font style="color:205375">Perform Single Prediction on a Test Video</font>**
#
# Now we will utilize the function **`predict_single_action()`** created above to perform a single prediction on a complete youtube test video that we will download using the function **`download_youtube_videos()`**, we had created above.

# %%
# Download the youtube video.
video_title = download_youtube_videos('https://www.youtube.com/watch?v=Ebk5o9aU2VM', test_videos_directory)

# Construct tihe nput youtube video path
input_video_file_path = f'{test_videos_directory}/{video_title}.mp4'

# Perform Single Prediction on the Test Video.
predict_single_action(input_video_file_path, SEQUENCE_LENGTH)

# Display the input video.
VideoFileClip(input_video_file_path, audio=False, target_resolution=(300,None)).ipython_display()
